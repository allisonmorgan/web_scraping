# %% [markdown]
# # Collecting Digital Trace Data: Web Scraping / APIs
# June 19th, 2018 - Javier Garcia-Bernardo & Allie Morgan

# %%
## Requirements
import requests               # Simple HTTP operations (GET and POST)
import selenium               # Loads dynamic (javascript) pages
import json                   # Parsing the responses from APIs
import re                     # Python library for parsing regular expressions
from bs4 import BeautifulSoup # Parsing HTML

# %% [markdown]
# ## Web Scraping

# %% [markdown]
# [Web scraping](https://en.wikipedia.org/wiki/Web_scraping) is a method for extracting data from the web. There are many techniques which can be used for web scraping — ranging from requiring human involvement (“human copy-paste”) to fully automated systems (using computer vision). Somewhere in the middle is HTML parsing, which we will describe here.
#
# Web scraping using [HTML parsing](https://en.wikipedia.org/wiki/Web_scraping#HTML_parsing) is often used on webpages which share similar HTML structure. For example, you might want to scrape the ingredients from chocolate chip cookie recipes to identify correlations between ingredients and five-star worthy cookies, or you might want to predict who will win March Madness by looking at game play-by-plays, or you want to know all the local pets up for adoption.

# %% [markdown]
# ### Static Webpages

# %%
pet_pages = ["https://www.boulderhumane.org/animals/adoption/dogs", 
             "https://www.boulderhumane.org/animals/adoption/cats", 
             "https://www.boulderhumane.org/animals/adoption/adopt_other"]

r = requests.get(pet_pages[0])
html = r.text
print(html[:500]) # Print the first 500 characters of the HTML
# Out:
# <!DOCTYPE html>
# <head>
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta charset="utf-8" />
# <link rel="shortcut icon" href="https://www.boulderhumane.org/sites/default/files/favicon.ico" type="image/vnd.microsoft.icon" />
# <meta name="Generator" content="Drupal 7 (http://drupal.org)" />
# <meta name="viewport" content="width=1000px, initial-scale=1.0, maximum-scale=1.0" />
# <title>Dogs Available for Adoption | Humane Society of Boulder Valley</title>
# <link type="text/css" rel="stylesheet

# %% [markdown]
# When you visit a webpage, your web browser renders an HTML document with CSS and Javascript to produce a visually appealing page. (See the HTML above.) [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/) is a Python library for parsing HTML. We'll use it to extract all of the names, ages, and breeds of the [dogs](https://www.boulderhumane.org/animals/adoption/dogs), [cats](https://www.boulderhumane.org/animals/adoption/cats), and [small animals](https://www.boulderhumane.org/animals/adoption/adopt_other) currently up for adoption at the Boulder Humane Society.

# %%
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# Note, that the feature of these pages which we are exploiting is their repeated HTML structure. Every animal listed has the following HTML variant:
# ```{html}
# <div class="views-row ... ">
#   ...
#   <div class="views-field views-field-field-pp-animalname">
#     <div class="field-content">
#       <a href="/animals/adoption/" title="Adopt Me!">Romeo</a>
#     </div>
#   </div>
#   <div class="views-field views-field-field-pp-primarybreed">
#     <div class="field-content">New Zealand</div>
#   </div>
#   <div class="views-field views-field-field-pp-secondarybreed">
#     <div class="field-content">Rabbit</div>
#   </div>
#   <div class="views-field views-field-field-pp-age">
#     ...
#     <span class="field-content">0 years 2 months</span>
#   </div>
#   <div class="views-field views-field-field-pp-gender">
#     ...
#     <span class="field-content">Male</span>
#   </div>
#   ...
# </div>
# ```
# So to get at the HTML object for each pet, we can run the following:

# %%
pets = soup.find_all('div', {'class': re.compile('.*views-row.*')})

# %% [markdown]
# That is, find all of the `div` tags with the `class` attribute which contains the string `views-row`.
#
# Next to grab the name, breeds, and ages of these pets, we’ll grab the children of each pet HTML object. For example:

# %%
head = "views-field views-field-field-pp-"
for pet in pets:
    name = pet.find('div', {'class': head + 'animalname'}).get_text(strip=True)
    primary_breed = pet.find('div', {'class': head + 'primarybreed'}).get_text(strip=True)
    secondary_breed = pet.find('div', {'class': head + 'secondarybreed'}).get_text(strip=True)
    age = pet.find('div', {'class': head + 'age'}).get_text(strip=True)
    print(name, primary_breed, secondary_breed, age)
# Out:
# (u'Audi', u'Belgian Malinois', u'', u'Age:5 years 7 months')
# (u'Kobe', u'Cane Corso', u'', u'Age:1 year 8 months')
# (u'Roxy', u'Terrier, American Pit Bull', u'Mix', u'Age:1 year 6 months')
# (u'Bear', u'Retriever, Chesapeake Bay', u'Mix', u'Age:2 years 5 months')
# (u'Chloe', u'Akita', u'Mix', u'Age:5 years 0 months')
# (u'Drew', u'Retriever, Labrador', u'Retriever, Golden', u'Age:2 years 0 months')
# (u'Harley', u'Terrier, American Pit Bull', u'Mix', u'Age:2 years 0 months')
# (u'Sadie', u'Great Dane', u'Retriever, Labrador', u'Age:8 years 10 months')
# (u'Megrita', u'Dutch Shepherd', u'Mix', u'Age:5 years 0 months')
# (u'Molly', u'Mastiff', u'Rottweiler', u'Age:8 years 0 months')
# (u'Butterbean', u'Terrier, Jack Russell', u'Mix', u'Age:7 years 0 months')
# (u'Rowdy', u'Rottweiler', u'Mix', u'Age:6 years 0 months')
# (u'Marco', u'Spaniel, American Cocker', u'', u'Age:5 years 0 months')
# (u'Eva', u'Boxer', u'Mix', u'Age:6 years 0 months')
# (u'Stew', u'Chihuahua, Short Coat', u'Mix', u'Age:7 years 0 months')
# (u'Tom', u'Beagle', u'Mix', u'Age:10 years 0 months')
# (u'Jenny', u'Coonhound, Black and Tan', u'', u'Age:6 years 3 months')
# (u'Sandy May', u'Coonhound', u'Mix', u'Age:7 years 0 months')
# (u'Bruno', u'Vizsla, Smooth Haired', u'Beagle', u'Age:1 year 6 months')
# (u'Fen', u'Pointer', u'Mix', u'Age:1 year 7 months')
# (u'Elijah', u'Terrier, American Pit Bull', u'Mix', u'Age:0 years 8 months')
# (u'Madre', u'Terrier, American Pit Bull', u'Mix', u'Age:3 years 1 month')
# (u'Ben', u'Shih Tzu', u'Mix', u'Age:2 years 3 months')
# (u'Lulu', u'Boxer', u'Mix', u'Age:4 years 6 months')
# (u'Sahara', u'Siberian Husky', u'Mix', u'Age:2 years 0 months')
# (u'Porter', u'Australian Cattle Dog', u'', u'Age:3 years 0 months')
# (u'Penny', u'Retriever, Labrador', u'Mix', u'Age:1 year 0 months')
# (u'Baloo', u'Beagle', u'Mix', u'Age:0 years 8 months')
# (u'Kira', u'Australian Cattle Dog', u'Mix', u'Age:1 year 1 month')
# (u'Rocky', u'Retriever, Labrador', u'Mix', u'Age:3 years 1 month')
# (u'Rosco', u'German Shepherd', u'Siberian Husky', u'Age:2 years 6 months')
# (u'Napoleon', u'Boxer', u'Mix', u'Age:0 years 6 months')
# (u'Poppy', u'Siberian Husky', u'', u'Age:1 year 6 months')
# (u'Willow', u'Australian Shepherd', u'Mix', u'Age:3 years 0 months')
# (u'Patty', u'Chihuahua, Short Coat', u'Dachshund, Miniature Smooth Haired', u'Age:0 years 6 months')
# (u'Suzie', u'Australian Shepherd', u'Mix', u'Age:0 years 2 months')
# (u'Gracie', u'Border Collie', u'Mix', u'Age:0 years 4 months')
# (u'Scooter', u'Australian Cattle Dog', u'Mix', u'Age:0 years 3 months')
# (u'Koda', u'Siberian Husky', u'', u'Age:2 years 6 months')
# (u'Willow', u'Retriever, Labrador', u'Mix', u'Age:0 years 6 months')

# %% [markdown]
# where each call to `find` is getting the children of a pet object, in particular, the `div`s with `class` attributes which look like `views-field views-field-field-pp-*`. Feel free to replace the above code with the cat or small animal pages provided and see how the output changes.

# %% [markdown]
# ### Dynamic (Javascript) Webpages

# %% [markdown]
# Above, we requested webpages that required no [Javascript](https://en.wikipedia.org/wiki/JavaScript). In other words, there was no input required on the users' end to view the content of the page (e.g. a login). Let's try a more complicated example of webscraping where content is loaded dynamically.
#
# Some characteristics of HTML scraping with [Selenium](https://www.seleniumhq.org/download/) it: (b) can handle javascript, (c) get **HTML** back after the Javascript has been rendered, (d) can behave like a person, though it (a) can be slow.
#
# Requirements (one of the below):
# - Firefox + geckodriver (https://github.com/mozilla/geckodriver/releases)
# - Chrome + chromedriver (https://sites.google.com/a/chromium.org/chromedriver/)
#
# Note: geckodriver/chromedriver must have execution permissions (chmod +x geckodriver)

# %%
import selenium.webdriver

# %% [markdown]
# Start the browser and define how much are you willing to wait for a page to load. (Many times this is not needed but it doesn't hurt.)

# %%
# Open the driver (change the executable path to geckodriver_mac.exe or geckodriver.exe)
# driver = selenium.webdriver.Chrome(executable_path="./chromedriver")
driver = selenium.webdriver.Chrome()
driver.implicitly_wait(10)
driver.set_page_load_timeout(30)

# %% [markdown]
# Visit [xkcd](https://xkcd.com) and click through the comics.

# %%
# Get the xkcd website
driver.get("https://xkcd.com/")

# %%
# Let's find the 'random' buttom
element = driver.find_element_by_xpath('//*[@id="middleContainer"]/ul[1]/li[3]/a')
element.click()

# %% [markdown]
# Find an attribute of this page.

# %%
element = driver.find_element_by_xpath('//*[@id="comic"]/img')
element.get_attribute("title")
# Out:
# u"Grayton also proposed making college scholarships available exclusively to sexually active teens, amnesty for illegal immigrants who create room for themselves by killing a citizen, and a graduated income tax based on penis size. He has been endorsed by Tracy Morgan, John Wilkes Booth's ghost, and the Time Cube guy."

# %% [markdown]
# Let's visit a webpage which requires a login. Signing in to Facebook ...

# %%
##DO NOT WRITE YOUR PASSWORD IN NOTEBOOKS!!
fb_email, fb_pass = "f1692418@mvrht.com","pedropalotes"

# %%
# Go to Facebook
driver.get("https://www.facebook.com/")

# %%
# Send email and password
driver.find_element_by_xpath('//*[@id="email"]').send_keys(fb_email)
driver.find_element_by_xpath('//*[@id="pass"]').send_keys(fb_pass)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-38-3d0448bb9d26> in <module>()
#       1 # Send email and password
# ----> 2 driver.find_element_by_xpath('//*[@id="email"]').send_keys(fb_email)
#       3 driver.find_element_by_xpath('//*[@id="pass"]').send_keys(fb_pass)
#
# /anaconda2/lib/python2.7/site-packages/selenium/webdriver/remote/webelement.pyc in send_keys(self, *value)
#     477         self._execute(Command.SEND_KEYS_TO_ELEMENT,
#     478                       {'text': "".join(keys_to_typing(value)),
# --> 479                        'value': keys_to_typing(value)})
#     480
#     481     # RenderedWebElement Items
#
# /anaconda2/lib/python2.7/site-packages/selenium/webdriver/remote/webelement.pyc in _execute(self, command, params)
#     626             params = {}
#     627         params['id'] = self._id
# --> 628         return self._parent.execute(command, params)
#     629
#     630     def find_element(self, by=By.ID, value=None):
#
# /anaconda2/lib/python2.7/site-packages/selenium/webdriver/remote/webdriver.pyc in execute(self, driver_command, params)
#     310         response = self.command_executor.execute(driver_command, params)
#     311         if response:
# --> 312             self.error_handler.check_response(response)
#     313             response['value'] = self._unwrap_value(
#     314                 response.get('value', None))
#
# /anaconda2/lib/python2.7/site-packages/selenium/webdriver/remote/errorhandler.pyc in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: unknown error: call function result missing 'value'
#   (Session info: chrome=67.0.3396.87)
#   (Driver info: chromedriver=2.33.506106 (8a06c39c4582fbfbab6966dbb1c38a9173bfb1a2),platform=Mac OS X 10.13.5 x86_64)

# %%
# Click on login
driver.find_element_by_xpath('//*[@id="loginbutton"]').click()

# %%
# Find JP
element = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div/form/div/div/div/div/input[2]')
element.send_keys("john paul gonzales")
element = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div[1]/div/div/div/div[1]/div[2]/div/form/button')
element.click()

# %%
# Click on him
element = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[1]/div/div[3]/div[2]/div/div/div[3]/div/div/div/div[1]/div/div/div/div/div/div[2]/div[1]/div/div[1]/a/div')
element.click()

# %%
# Send a friend request
element = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[1]/div/div[2]/div[2]/div[2]/div/div[1]/div/div[4]/div/div[2]/div/div[2]/span/span/span[1]/a')
element.click()

# %%
# Always remember to close your browser!
driver.close()

# %% [markdown]
# ## APIs

# %% [markdown]
# To allow users to access large amounts of data, companies may provide an [Application Programming Interface (API)](https://en.wikipedia.org/wiki/Application_programming_interface). Often these request are handled via PUT and POST HTTP requests. For example, to make a request from the Twitter API:
#
# ```{bash}
# curl --request GET
#  --url 'https://api.twitter.com/1.1/search/tweets.json?q=nasa&result_type=popular'
#  --header 'authorization: OAuth oauth_consumer_key="consumer-key-for-app", ... ,
#  oauth_token="access-token-for-authed-user", oauth_version="1.0"'
#  ```
#
# APIs often return data in the format of [Javascript Object Notation (JSON)](https://en.wikipedia.org/wiki/JSON). For example:
#
# ```{json}
# {"status": 200, "message": "hello world"}
# ```

# %% [markdown]
# ### "Hidden" APIs
#
# First, let's try and access what we are calling a "hidden" API. That is, we investigate the resources requested by a webpage (e.g. a list of faculty), and make requests directly to that API.

# %%
import requests
import json

def get_names(letters):
    params = (
        ('name', letters),
        ('request_num', '1'),
    )

    response = requests.get('https://www.uvm.edu/directory/api/query_results.php', params=params)
    if response.ok == True:
        return response.text
    else:
        return None

# %%
response = get_names("ab")

# %%
response_json = json.loads(response)
response_json
# Out:
# {u'authenticated': u'',
#  u'data': [{u'0': u'uvmedubroadcastflag',
#    u'1': u'uvmeduuuid',
#    u'10': u'edupersonprimaryaffiliation',
#    u'11': u'uvmeduprimaryaffiliation',
#    u'12': u'ou',
#    u'13': u'title',
#    u'14': u'cn',
#    u'15': u'givenname',
#    u'16': u'postaladdress',
#    u'17': u'mailroutingaddress',
#    u'18': u'uid',
#    u'19': u'uidnumber',
#    u'2': u'edupersonaffiliation',
#    u'20': u'gidnumber',
#    u'21': u'gecos',
#    u'22': u'homedirectory',
#    u'23': u'loginshell',
#    u'24': u'edupersonprincipalname',
#    u'25': u'mail',
#    u'26': u'uvmedualias',
#    u'27': u'telephonenumber',
#    u'3': u'uvmeduaffiliation',
#    u'4': u'sn',
#    u'5': u'uvmedusurname',
#    u'6': u'uvmaltuid',
#    u'7': u'uvmaltgid',
#    u'8': u'uvmalthomedir',
#    u'9': u'edupersonentitlement',
#    u'cn': {u'0': u'Abraham Isaac Sender', u'count': u'1'},
#    u'count': u'28',
#    u'dn': u'uid=asender,ou=People,dc=uvm,dc=edu',
#    u'edupersonaffiliation': {u'0': u'Alum',
#     u'1': u'Affiliate',
#     u'count': u'2'},
#    u'edupersonentitlement': {u'0': u'urn:mace:uvm.edu:pgp:encryption-comis',
#     u'1': u'urn:mace:uvm.edu:ets:unix-login',
#     u'2': u'urn:mace:uvm.edu:ets:software-download',
#     u'3': u'urn:mace:uvm.edu:ets:unix-filespace',
#     u'4': u'urn:mace:uvm.edu:ets:email',
#     u'5': u'urn:mace:uvm.edu:ets:ad-login',
#     u'6': u'urn:mace:uvm.edu:ets:banner-access',
#     u'count': u'7'},
#    u'edupersonprimaryaffiliation': {u'0': u'Affiliate', u'count': u'1'},
#    u'edupersonprincipalname': {u'0': u'asender@uvm.edu', u'count': u'1'},
#    u'filter_field': u'cn',
#    u'from_filter': u'firstLast',
#    u'gecos': {u'0': u'Abraham Isaac Sender', u'count': u'1'},
#    u'gidnumber': {u'0': u'100', u'count': u'1'},
#    u'givenname': {u'0': u'Abraham', u'count': u'1'},
#    u'homedirectory': {u'0': u'/users/a/s/asender', u'count': u'1'},
#    u'loginshell': {u'0': u'/bin/bash', u'count': u'1'},
#    u'mail': {u'0': u'asender@uvm.edu', u'count': u'1'},
#    u'mailroutingaddress': {u'0': u'asender@msx-po.uvm.edu', u'count': u'1'},
#    u'ou': {u'0': u'Med-Pulmonary', u'count': u'1'},
#    u'postaladdress': {u'0': u'Med-Pulmonary$Given Bldg D206$USA',
#     u'count': u'1'},
#    u'sn': {u'0': u'Sender', u'count': u'1'},
#    u'telephonenumber': {u'0': u'+1 802-656-3505', u'count': u'1'},
#    u'title': {u'0': u'Affiliated Org Employee', u'count': u'1'},
#    u'uid': {u'0': u'asender', u'count': u'1'},
#    u'uidnumber': {u'0': u'163364', u'count': u'1'},
#    u'uvmaltgid': {u'0': u'502', u'count': u'1'},
#    u'uvmalthomedir': {u'0': u'/Users/Customer', u'count': u'1'},
#    u'uvmaltuid': {u'0': u'502', u'count': u'1'},
#    u'uvmeduaffiliation': {u'0': u'Former Student',
#     u'1': u'Affiliated Organization Employee',
#     u'count': u'2'},
#    u'uvmedualias': {u'0': u'asender', u'1': u'Abraham.Sender', u'count': u'2'},
#    u'uvmedubroadcastflag': {u'0': u'a', u'count': u'1'},
#    u'uvmeduprimaryaffiliation': {u'0': u'Affiliated Organization Employee',
#     u'count': u'1'},
#    u'uvmedusurname': {u'0': u'Sender', u'count': u'1'},
#    u'uvmeduuuid': {u'0': u'fbc0019c-c8a1-11da-96a6-d0e9f2a749f2',
#     u'count': u'1'}},
#   {u'0': u'uvmedualias',
#    u'1': u'edupersonprincipalname',
#    u'10': u'uvmeduaffiliation',
#    u'11': u'cn',
#    u'12': u'givenname',
#    u'13': u'sn',
#    u'14': u'uvmedusurname',
#    u'15': u'uvmaltuid',
#    u'16': u'uvmaltgid',
#    u'17': u'uvmalthomedir',
#    u'18': u'loginshell',
#    u'19': u'edupersonprimaryaffiliation',
#    u'2': u'mail',
#    u'20': u'ou',
#    u'21': u'edupersonentitlement',
#    u'22': u'postaladdress',
#    u'23': u'uvmeduofficelocation',
#    u'24': u'uvmeduofficephone',
#    u'25': u'labeleduri',
#    u'26': u'uvmedubroadcastflag',
#    u'27': u'title',
#    u'28': u'uvmeduprimaryaffiliation',
#    u'29': u'mailroutingaddress',
#    u'3': u'gidnumber',
#    u'4': u'homedirectory',
#    u'5': u'uidnumber',
#    u'6': u'uid',
#    u'7': u'uvmeduuuid',
#    u'8': u'gecos',
#    u'9': u'edupersonaffiliation',
#    u'cn': {u'0': u'Abigail Miles Crocker', u'count': u'1'},
#    u'count': u'30',
#    u'dn': u'uid=acrocker,ou=People,dc=uvm,dc=edu',
#    u'edupersonaffiliation': {u'0': u'Affiliate',
#     u'1': u'Faculty',
#     u'2': u'Alum',
#     u'count': u'3'},
#    u'edupersonentitlement': {u'0': u'urn:mace:uvm.edu:pgp:encryption',
#     u'1': u'urn:mace:uvm.edu:ets:unix-login',
#     u'2': u'urn:mace:uvm.edu:ets:software-download',
#     u'3': u'urn:mace:uvm.edu:ets:unix-filespace',
#     u'4': u'urn:mace:uvm.edu:ets:email',
#     u'5': u'urn:mace:uvm.edu:ets:ad-login',
#     u'6': u'urn:mace:uvm.edu:ets:ad-filespace',
#     u'7': u'urn:mace:uvm.edu:ets:banner-access',
#     u'count': u'8'},
#    u'edupersonprimaryaffiliation': {u'0': u'Faculty', u'count': u'1'},
#    u'edupersonprincipalname': {u'0': u'acrocker@uvm.edu', u'count': u'1'},
#    u'filter_field': u'cn',
#    u'from_filter': u'firstLast',
#    u'gecos': {u'0': u'Abigail Miles Crocker', u'count': u'1'},
#    u'gidnumber': {u'0': u'100', u'count': u'1'},
#    u'givenname': {u'0': u'Abigail', u'count': u'1'},
#    u'homedirectory': {u'0': u'/users/a/c/acrocker', u'count': u'1'},
#    u'labeleduri': {u'0': u'http://www.uvm.edu/~acrocker', u'count': u'1'},
#    u'loginshell': {u'0': u'/bin/bash', u'count': u'1'},
#    u'mail': {u'0': u'Abigail.Crocker@uvm.edu', u'count': u'1'},
#    u'mailroutingaddress': {u'0': u'acrocker@msx-po.uvm.edu', u'count': u'1'},
#    u'ou': {u'0': u'Mathematics &amp; Statistics', u'count': u'1'},
#    u'postaladdress': {u'0': u'Math &amp; Stats$16 Colchester Ave.$USA',
#     u'count': u'1'},
#    u'sn': {u'0': u'Crocker', u'count': u'1'},
#    u'title': {u'0': u'Research Assistant Prof',
#     u'1': u'Lecturer',
#     u'count': u'2'},
#    u'uid': {u'0': u'acrocker', u'count': u'1'},
#    u'uidnumber': {u'0': u'9716', u'count': u'1'},
#    u'uvmaltgid': {u'0': u'502', u'count': u'1'},
#    u'uvmalthomedir': {u'0': u'/Users/Customer', u'count': u'1'},
#    u'uvmaltuid': {u'0': u'502', u'count': u'1'},
#    u'uvmeduaffiliation': {u'0': u'Banner Course Assignment',
#     u'1': u'Former Student',
#     u'2': u'Non-Salaried Faculty',
#     u'3': u'9 Month Faculty',
#     u'4': u'EAB Advisor',
#     u'count': u'5'},
#    u'uvmedualias': {u'0': u'Abigail.Crocker', u'count': u'1'},
#    u'uvmedubroadcastflag': {u'0': u'a', u'count': u'1'},
#    u'uvmeduofficelocation': {u'0': u'104 Mansfield House', u'count': u'1'},
#    u'uvmeduofficephone': {u'0': u'802-656-3089', u'count': u'1'},
#    u'uvmeduprimaryaffiliation': {u'0': u'9 Month Faculty', u'count': u'1'},
#    u'uvmedusurname': {u'0': u'Crocker', u'count': u'1'},
#    u'uvmeduuuid': {u'0': u'fc264d26-c8a1-11da-96a6-d0e9f2a749f2',
#     u'count': u'1'}},
#   {u'0': u'uvmedualias',
#    u'1': u'uvmedubroadcastflag',
#    u'10': u'gecos',
#    u'11': u'gidnumber',
#    u'12': u'homedirectory',
#    u'13': u'uidnumber',
#    u'14': u'uid',
#    u'15': u'uvmeduuuid',
#    u'16': u'uvmedusurname',
#    u'17': u'title',
#    u'18': u'uvmeduaffiliation',
#    u'19': u'uvmeduprimaryaffiliation',
#    u'2': u'edupersonprincipalname',
#    u'20': u'edupersonaffiliation',
#    u'21': u'edupersonprimaryaffiliation',
#    u'22': u'edupersonentitlement',
#    u'23': u'loginshell',
#    u'24': u'ou',
#    u'25': u'mailroutingaddress',
#    u'26': u'telephonenumber',
#    u'27': u'postaladdress',
#    u'3': u'mail',
#    u'4': u'cn',
#    u'5': u'givenname',
#    u'6': u'sn',
#    u'7': u'uvmaltuid',
#    u'8': u'uvmaltgid',
#    u'9': u'uvmalthomedir',
#    u'cn': {u'0': u'Abiy B. Ambaye', u'count': u'1'},
#    u'count': u'28',
#    u'dn': u'uid=aambaye,ou=People,dc=uvm,dc=edu',
#    u'edupersonaffiliation': {u'0': u'Faculty',
#     u'1': u'Affiliate',
#     u'count': u'2'},
#    u'edupersonentitlement': {u'0': u'urn:mace:uvm.edu:pgp:encryption-comis',
#     u'1': u'urn:mace:uvm.edu:ets:unix-login',
#     u'2': u'urn:mace:uvm.edu:ets:software-download',
#     u'3': u'urn:mace:uvm.edu:ets:unix-filespace',
#     u'4': u'urn:mace:uvm.edu:ets:email',
#     u'5': u'urn:mace:uvm.edu:ets:ad-login',
#     u'6': u'urn:mace:uvm.edu:ets:ad-filespace',
#     u'7': u'urn:mace:uvm.edu:ets:banner-access',
#     u'count': u'8'},
#    u'edupersonprimaryaffiliation': {u'0': u'Faculty', u'count': u'1'},
#    u'edupersonprincipalname': {u'0': u'aambaye@uvm.edu', u'count': u'1'},
#    u'filter_field': u'cn',
#    u'from_filter': u'firstLast',
#    u'gecos': {u'0': u'Abiy B. Ambaye', u'count': u'1'},
#    u'gidnumber': {u'0': u'100', u'count': u'1'},
#    u'givenname': {u'0': u'Abiy', u'count': u'1'},
#    u'homedirectory': {u'0': u'/users/a/a/aambaye', u'count': u'1'},
#    u'loginshell': {u'0': u'/bin/bash', u'count': u'1'},
#    u'mail': {u'0': u'Abiy.Ambaye@uvm.edu', u'count': u'1'},
#    u'mailroutingaddress': {u'0': u'aambaye@msx-po.uvm.edu', u'count': u'1'},
#    u'ou': {u'0': u'PathLabMed - Anatomic', u'count': u'1'},
#    u'postaladdress': {u'0': u'Pathology &amp; Laboratory Medicine$UVM Medical Center, ACC, EP2$USA',
#     u'count': u'1'},
#    u'sn': {u'0': u'Ambaye', u'count': u'1'},
#    u'telephonenumber': {u'0': u'+1 802-847-9916', u'count': u'1'},
#    u'title': {u'0': u'Associate Professor', u'count': u'1'},
#    u'uid': {u'0': u'aambaye', u'count': u'1'},
#    u'uidnumber': {u'0': u'56261', u'count': u'1'},
#    u'uvmaltgid': {u'0': u'502', u'count': u'1'},
#    u'uvmalthomedir': {u'0': u'/Users/Customer', u'count': u'1'},
#    u'uvmaltuid': {u'0': u'502', u'count': u'1'},
#    u'uvmeduaffiliation': {u'0': u'12 Month Faculty',
#     u'1': u'Banner Course Assignment',
#     u'2': u'EAB Advisor',
#     u'count': u'3'},
#    u'uvmedualias': {u'0': u'Abiy.Ambaye', u'count': u'1'},
#    u'uvmedubroadcastflag': {u'0': u'a', u'count': u'1'},
#    u'uvmeduprimaryaffiliation': {u'0': u'12 Month Faculty', u'count': u'1'},
#    u'uvmedusurname': {u'0': u'Ambaye', u'count': u'1'},
#    u'uvmeduuuid': {u'0': u'fdc4f588-c8a1-11da-96a6-d0e9f2a749f2',
#     u'count': u'1'}},
#   {u'0': u'edupersonprincipalname',
#    u'1': u'uvmedubroadcastflag',
#    u'10': u'edupersonaffiliation',
#    u'11': u'uvmeduaffiliation',
#    u'12': u'cn',
#    u'13': u'givenname',
#    u'14': u'sn',
#    u'15': u'uvmedusurname',
#    u'16': u'uvmaltuid',
#    u'17': u'uvmaltgid',
#    u'18': u'uvmalthomedir',
#    u'19': u'loginshell',
#    u'2': u'gidnumber',
#    u'20': u'edupersonentitlement',
#    u'21': u'mail',
#    u'22': u'uvmedualias',
#    u'23': u'ou',
#    u'24': u'uvmeduofficelocation',
#    u'25': u'postaladdress',
#    u'26': u'uvmeduofficephone',
#    u'27': u'uvmeduofficeaddress',
#    u'28': u'mailroutingaddress',
#    u'29': u'title',
#    u'3': u'homedirectory',
#    u'30': u'telephonenumber',
#    u'4': u'uidnumber',
#    u'5': u'uid',
#    u'6': u'uvmeduuuid',
#    u'7': u'gecos',
#    u'8': u'edupersonprimaryaffiliation',
#    u'9': u'uvmeduprimaryaffiliation',
#    u'cn': {u'0': u'Abbey L. Peterson', u'count': u'1'},
#    u'count': u'31',
#    u'dn': u'uid=aldattil,ou=People,dc=uvm,dc=edu',
#    u'edupersonaffiliation': {u'0': u'Staff', u'1': u'Alum', u'count': u'2'},
#    u'edupersonentitlement': {u'0': u'urn:mace:uvm.edu:pgp:encryption',
#     u'1': u'urn:mace:uvm.edu:ets:unix-login',
#     u'2': u'urn:mace:uvm.edu:ets:software-download',
#     u'3': u'urn:mace:uvm.edu:ets:unix-filespace',
#     u'4': u'urn:mace:uvm.edu:ets:email',
#     u'5': u'urn:mace:uvm.edu:ets:ad-login',
#     u'6': u'urn:mace:uvm.edu:ets:ad-filespace',
#     u'7': u'urn:mace:uvm.edu:ets:banner-access',
#     u'count': u'8'},
#    u'edupersonprimaryaffiliation': {u'0': u'Staff', u'count': u'1'},
#    u'edupersonprincipalname': {u'0': u'aldattil@uvm.edu', u'count': u'1'},
#    u'filter_field': u'cn',
#    u'from_filter': u'firstLast',
#    u'gecos': {u'0': u'Abbey L. Peterson', u'count': u'1'},
#    u'gidnumber': {u'0': u'100', u'count': u'1'},
#    u'givenname': {u'0': u'Abbey', u'count': u'1'},
#    u'homedirectory': {u'0': u'/users/a/l/aldattil', u'count': u'1'},
#    u'loginshell': {u'0': u'/bin/bash', u'count': u'1'},
#    u'mail': {u'0': u'Abbey.Peterson@uvm.edu', u'count': u'1'},
#    u'mailroutingaddress': {u'0': u'aldattil@msx-po.uvm.edu', u'count': u'1'},
#    u'ou': {u'0': u'Research Protections Office', u'count': u'1'},
#    u'postaladdress': {u'0': u'Research Protections Office$Waterman Building RM 213$USA',
#     u'count': u'1'},
#    u'sn': {u'0': u'Peterson', u'count': u'1'},
#    u'telephonenumber': {u'0': u'+1 802-656-8805', u'count': u'1'},
#    u'title': {u'0': u'Research Review Analyst', u'count': u'1'},
#    u'uid': {u'0': u'aldattil', u'count': u'1'},
#    u'uidnumber': {u'0': u'22164', u'count': u'1'},
#    u'uvmaltgid': {u'0': u'502', u'count': u'1'},
#    u'uvmalthomedir': {u'0': u'/Users/Customer', u'count': u'1'},
#    u'uvmaltuid': {u'0': u'502', u'count': u'1'},
#    u'uvmeduaffiliation': {u'0': u'12 Month Staff',
#     u'1': u'Former Student',
#     u'count': u'2'},
#    u'uvmedualias': {u'0': u'Abbey.Peterson', u'count': u'1'},
#    u'uvmedubroadcastflag': {u'0': u'a', u'count': u'1'},
#    u'uvmeduofficeaddress': {u'0': u'213 Waterman', u'count': u'1'},
#    u'uvmeduofficelocation': {u'0': u'213 Waterman', u'count': u'1'},
#    u'uvmeduofficephone': {u'0': u'656-8805', u'count': u'1'},
#    u'uvmeduprimaryaffiliation': {u'0': u'12 Month Staff', u'count': u'1'},
#    u'uvmedusurname': {u'0': u'Peterson', u'count': u'1'},
#    u'uvmeduuuid': {u'0': u'fe042fa0-c8a1-11da-96a6-d0e9f2a749f2',
#     u'count': u'1'}},
#   {u'0': u'uvmedubroadcastflag',
#    u'1': u'edupersonprincipalname',
#    u'10': u'uvmeduprimaryaffiliation',
#    u'11': u'edupersonaffiliation',
#    u'12': u'uvmeduaffiliation',
#    u'13': u'ou',
#    u'14': u'cn',
#    u'15': u'givenname',
#    u'16': u'sn',
#    u'17': u'uvmedusurname',
#    u'18': u'uvmaltuid',
#    u'19': u'uvmaltgid',
#    u'2': u'mail',
#    u'20': u'uvmalthomedir',
#    u'21': u'gecos',
#    u'22': u'edupersonentitlement',
#    u'23': u'loginshell',
#    u'24': u'postaladdress',
#    u'25': u'mailroutingaddress',
#    u'26': u'telephonenumber',
#    u'27': u'title',
#    u'28': u'uvmeduvaccprimarygroup',
#    u'3': u'uvmedualias',
#    u'4': u'gidnumber',
#    u'5': u'homedirectory',
#    u'6': u'uidnumber',
#    u'7': u'uid',
#    u'8': u'uvmeduuuid',
#    u'9': u'edupersonprimaryaffiliation',
#    u'cn': {u'0': u'Abby Katrien van den Berg', u'count': u'1'},
#    u'count': u'29',
#    u'dn': u'uid=avan,ou=People,dc=uvm,dc=edu',
#    u'edupersonaffiliation': {u'0': u'Faculty',
#     u'1': u'Alum',
#     u'2': u'Affiliate',
#     u'count': u'3'},
#    u'edupersonentitlement': {u'0': u'urn:mace:uvm.edu:pgp:encryption',
#     u'1': u'urn:mace:uvm.edu:ets:unix-login',
#     u'2': u'urn:mace:uvm.edu:ets:software-download',
#     u'3': u'urn:mace:uvm.edu:ets:unix-filespace',
#     u'4': u'urn:mace:uvm.edu:ets:email',
#     u'5': u'urn:mace:uvm.edu:ets:ad-login',
#     u'6': u'urn:mace:uvm.edu:ets:ad-filespace',
#     u'7': u'urn:mace:uvm.edu:ets:banner-access',
#     u'count': u'8'},
#    u'edupersonprimaryaffiliation': {u'0': u'Faculty', u'count': u'1'},
#    u'edupersonprincipalname': {u'0': u'avan@uvm.edu', u'count': u'1'},
#    u'filter_field': u'cn',
#    u'from_filter': u'firstLast',
#    u'gecos': {u'0': u'Abby Katrien van den Berg', u'count': u'1'},
#    u'gidnumber': {u'0': u'100', u'count': u'1'},
#    u'givenname': {u'0': u'Abby', u'count': u'1'},
#    u'homedirectory': {u'0': u'/users/a/v/avan', u'count': u'1'},
#    u'loginshell': {u'0': u'/bin/bash', u'count': u'1'},
#    u'mail': {u'0': u'Abby.vandenBerg@uvm.edu', u'count': u'1'},
#    u'mailroutingaddress': {u'0': u'avan@msx-po.uvm.edu', u'count': u'1'},
#    u'ou': {u'0': u'Plant Biology', u'count': u'1'},
#    u'postaladdress': {u'0': u'Proctor Maple Research Center$P.O. Box 233$Underhill Center, VT 05490$USA',
#     u'count': u'1'},
#    u'sn': {u'0': u'Berg',
#     u'1': u'den',
#     u'2': u'van',
#     u'3': u'van den Berg',
#     u'count': u'4'},
#    u'telephonenumber': {u'0': u'+1 802-899-9926',
#     u'1': u'+1 802-238-9529',
#     u'count': u'2'},
#    u'title': {u'0': u'Research Associate Prof',
#     u'1': u'Lecturer',
#     u'count': u'2'},
#    u'uid': {u'0': u'avan', u'count': u'1'},
#    u'uidnumber': {u'0': u'10683', u'count': u'1'},
#    u'uvmaltgid': {u'0': u'502', u'count': u'1'},
#    u'uvmalthomedir': {u'0': u'/Users/Customer', u'count': u'1'},
#    u'uvmaltuid': {u'0': u'502', u'count': u'1'},
#    u'uvmeduaffiliation': {u'0': u'12 Month Faculty',
#     u'1': u'Non-Salaried Faculty',
#     u'2': u'Former Student',
#     u'3': u'Banner Course Assignment',
#     u'count': u'4'},
#    u'uvmedualias': {u'0': u'Abby.vandenBerg', u'count': u'1'},
#    u'uvmedubroadcastflag': {u'0': u'a', u'count': u'1'},
#    u'uvmeduprimaryaffiliation': {u'0': u'12 Month Faculty', u'count': u'1'},
#    u'uvmedusurname': {u'0': u'van den Berg', u'count': u'1'},
#    u'uvmeduuuid': {u'0': u'0eead792-c8a2-11da-96a6-d0e9f2a749f2',
#     u'count': u'1'},
#    u'uvmeduvaccprimarygroup': {u'0': u'170005', u'count': u'1'}},
#   {u'0': u'uvmedubroadcastflag',
#    u'1': u'uvmedualias',
#    u'10': u'edupersonprimaryaffiliation',
#    u'11': u'edupersonaffiliation',
#    u'12': u'uvmeduaffiliation',
#    u'13': u'cn',
#    u'14': u'givenname',
#    u'15': u'sn',
#    u'16': u'uvmedusurname',
#    u'17': u'uvmaltuid',
#    u'18': u'uvmaltgid',
#    u'19': u'uvmalthomedir',
#    u'2': u'mail',
#    u'20': u'edupersonentitlement',
#    u'21': u'loginshell',
#    u'22': u'mailroutingaddress',
#    u'23': u'uvmeduprimaryaffiliation',
#    u'24': u'ou',
#    u'25': u'title',
#    u'26': u'postaladdress',
#    u'27': u'telephonenumber',
#    u'3': u'uidnumber',
#    u'4': u'gidnumber',
#    u'5': u'gecos',
#    u'6': u'homedirectory',
#    u'7': u'uid',
#    u'8': u'uvmeduuuid',
#    u'9': u'edupersonprincipalname',
#    u'cn': {u'0': u'Abigail S. McGowan', u'count': u'1'},
#    u'count': u'28',
#    u'dn': u'uid=amcgowan,ou=People,dc=uvm,dc=edu',
#    u'edupersonaffiliation': {u'0': u'Faculty',
#     u'1': u'Affiliate',
#     u'count': u'2'},
#    u'edupersonentitlement': {u'0': u'urn:mace:uvm.edu:pgp:encryption',
#     u'1': u'urn:mace:uvm.edu:ets:unix-login',
#     u'2': u'urn:mace:uvm.edu:ets:software-download',
#     u'3': u'urn:mace:uvm.edu:ets:unix-filespace',
#     u'4': u'urn:mace:uvm.edu:ets:email',
#     u'5': u'urn:mace:uvm.edu:ets:ad-login',
#     u'6': u'urn:mace:uvm.edu:ets:ad-filespace',
#     u'7': u'urn:mace:uvm.edu:ets:banner-access',
#     u'count': u'8'},
#    u'edupersonprimaryaffiliation': {u'0': u'Faculty', u'count': u'1'},
#    u'edupersonprincipalname': {u'0': u'amcgowan@uvm.edu', u'count': u'1'},
#    u'filter_field': u'cn',
#    u'from_filter': u'firstLast',
#    u'gecos': {u'0': u'Abigail S. McGowan', u'count': u'1'},
#    u'gidnumber': {u'0': u'100', u'count': u'1'},
#    u'givenname': {u'0': u'Abigail', u'count': u'1'},
#    u'homedirectory': {u'0': u'/users/a/m/amcgowan', u'count': u'1'},
#    u'loginshell': {u'0': u'/bin/bash', u'count': u'1'},
#    u'mail': {u'0': u'Abigail.McGowan@uvm.edu', u'count': u'1'},
#    u'mailroutingaddress': {u'0': u'amcgowan@msx-po.uvm.edu', u'count': u'1'},
#    u'ou': {u'0': u'A&amp;S Dean&#039; s Ofc',
#     u'1': u'History',
#     u'count': u'2'},
#    u'postaladdress': {u'0': u'Arts &amp; Sciences$Deans Office Rm 200$USA',
#     u'count': u'1'},
#    u'sn': {u'0': u'McGowan', u'count': u'1'},
#    u'telephonenumber': {u'0': u'+1 802-656-1273', u'count': u'1'},
#    u'title': {u'0': u'Associate Dean',
#     u'1': u'Associate Professor',
#     u'count': u'2'},
#    u'uid': {u'0': u'amcgowan', u'count': u'1'},
#    u'uidnumber': {u'0': u'70085', u'count': u'1'},
#    u'uvmaltgid': {u'0': u'502', u'count': u'1'},
#    u'uvmalthomedir': {u'0': u'/Users/Customer', u'count': u'1'},
#    u'uvmaltuid': {u'0': u'502', u'count': u'1'},
#    u'uvmeduaffiliation': {u'0': u'Banner Course Assignment',
#     u'1': u'Non-Salaried Faculty',
#     u'2': u'12 Month Faculty',
#     u'3': u'EAB Advisor',
#     u'count': u'4'},
#    u'uvmedualias': {u'0': u'Abigail.McGowan', u'count': u'1'},
#    u'uvmedubroadcastflag': {u'0': u'a', u'count': u'1'},
#    u'uvmeduprimaryaffiliation': {u'0': u'12 Month Faculty', u'count': u'1'},
#    u'uvmedusurname': {u'0': u'McGowan', u'count': u'1'},
#    u'uvmeduuuid': {u'0': u'1e0ad196-c8a2-11da-96a6-d0e9f2a749f2',
#     u'count': u'1'}},
#   {u'0': u'uvmedubroadcastflag',
#    u'1': u'uvmeduuuid',
#    u'10': u'uvmalthomedir',
#    u'11': u'uvmedualias',
#    u'12': u'edupersonentitlement',
#    u'13': u'uid',
#    u'14': u'edupersonprimaryaffiliation',
#    u'15': u'uvmeduprimaryaffiliation',
#    u'16': u'ou',
#    u'17': u'uidnumber',
#    u'18': u'gidnumber',
#    u'19': u'gecos',
#    u'2': u'edupersonaffiliation',
#    u'20': u'homedirectory',
#    u'21': u'loginshell',
#    u'22': u'edupersonprincipalname',
#    u'23': u'mailroutingaddress',
#    u'24': u'mail',
#    u'3': u'uvmeduaffiliation',
#    u'4': u'cn',
#    u'5': u'givenname',
#    u'6': u'sn',
#    u'7': u'uvmedusurname',
#    u'8': u'uvmaltuid',
#    u'9': u'uvmaltgid',
#    u'cn': {u'0': u'Abigayle Frances Smith', u'count': u'1'},
#    u'count': u'25',
#    u'dn': u'uid=afsmith,ou=People,dc=uvm,dc=edu',
#    u'edupersonaffiliation': {u'0': u'Alum', u'1': u'Student', u'count': u'2'},
#    u'edupersonentitlement': {u'0': u'urn:mace:uvm.edu:ets:banner-access',
#     u'1': u'urn:mace:uvm.edu:ets:unix-login',
#     u'2': u'urn:mace:uvm.edu:ets:software-download',
#     u'3': u'urn:mace:uvm.edu:ets:unix-filespace',
#     u'4': u'urn:mace:uvm.edu:ets:email',
#     u'5': u'urn:mace:uvm.edu:ets:ad-login',
#     u'count': u'6'},
#    u'edupersonprimaryaffiliation': {u'0': u'Student', u'count': u'1'},
#    u'edupersonprincipalname': {u'0': u'afsmith@uvm.edu', u'count': u'1'},
#    u'filter_field': u'cn',
#    u'from_filter': u'firstLast',
#    u'gecos': {u'0': u'Abigayle Frances Smith', u'count': u'1'},
#    u'gidnumber': {u'0': u'100', u'count': u'1'},
#    u'givenname': {u'0': u'Abigayle', u'count': u'1'},
#    u'homedirectory': {u'0': u'/users/a/f/afsmith', u'count': u'1'},
#    u'loginshell': {u'0': u'/bin/bash', u'count': u'1'},
#    u'mail': {u'0': u'abigayle.smith@uvm.edu', u'count': u'1'},
#    u'mailroutingaddress': {u'0': u'afsmith@msx-po.uvm.edu', u'count': u'1'},
#    u'ou': {u'0': u'Graduate', u'count': u'1'},
#    u'sn': {u'0': u'Smith', u'count': u'1'},
#    u'uid': {u'0': u'afsmith', u'count': u'1'},
#    u'uidnumber': {u'0': u'306883', u'count': u'1'},
#    u'uvmaltgid': {u'0': u'502', u'count': u'1'},
#    u'uvmalthomedir': {u'0': u'/Users/Customer', u'count': u'1'},
#    u'uvmaltuid': {u'0': u'502', u'count': u'1'},
#    u'uvmeduaffiliation': {u'0': u'Former Student',
#     u'1': u'Current Degree Student',
#     u'count': u'2'},
#    u'uvmedualias': {u'0': u'Abigayle.Smith', u'count': u'1'},
#    u'uvmedubroadcastflag': {u'0': u'a', u'count': u'1'},
#    u'uvmeduprimaryaffiliation': {u'0': u'Current Degree Student',
#     u'count': u'1'},
#    u'uvmedusurname': {u'0': u'Smith', u'count': u'1'},
#    u'uvmeduuuid': {u'0': u'256d7e70-c8a2-11da-96a6-d0e9f2a749f2',
#     u'count': u'1'}},
#   {u'0': u'uvmedubroadcastflag',
#    u'1': u'uvmeduuuid',
#    u'10': u'uvmalthomedir',
#    u'11': u'uid',
#    u'12': u'edupersonprimaryaffiliation',
#    u'13': u'uvmedualias',
#    u'14': u'mail',
#    u'15': u'uidnumber',
#    u'16': u'gidnumber',
#    u'17': u'homedirectory',
#    u'18': u'loginshell',
#    u'19': u'edupersonprincipalname',
#    u'2': u'edupersonaffiliation',
#    u'20': u'mailroutingaddress',
#    u'21': u'uvmeduprimaryaffiliation',
#    u'22': u'ou',
#    u'23': u'gecos',
#    u'24': u'edupersonentitlement',
#    u'25': u'telephonenumber',
#    u'3': u'uvmeduaffiliation',
#    u'4': u'cn',
#    u'5': u'givenname',
#    u'6': u'sn',
#    u'7': u'uvmedusurname',
#    u'8': u'uvmaltuid',
#    u'9': u'uvmaltgid',
#    u'cn': {u'0': u'Abigail Elizabeth Langsner', u'count': u'1'},
#    u'count': u'26',
#    u'dn': u'uid=alangsne,ou=People,dc=uvm,dc=edu',
#    u'edupersonaffiliation': {u'0': u'Alum', u'1': u'Student', u'count': u'2'},
#    u'edupersonentitlement': {u'0': u'urn:mace:uvm.edu:ets:unix-login',
#     u'1': u'urn:mace:uvm.edu:ets:software-download',
#     u'2': u'urn:mace:uvm.edu:ets:unix-filespace',
#     u'3': u'urn:mace:uvm.edu:ets:email',
#     u'4': u'urn:mace:uvm.edu:ets:ad-login',
#     u'5': u'urn:mace:uvm.edu:ets:banner-access',
#     u'count': u'6'},
#    u'edupersonprimaryaffiliation': {u'0': u'Student', u'count': u'1'},
#    u'edupersonprincipalname': {u'0': u'alangsne@uvm.edu', u'count': u'1'},
#    u'filter_field': u'cn',
#    u'from_filter': u'firstLast',
#    u'gecos': {u'0': u'Abigail Elizabeth Langsner', u'count': u'1'},
#    u'gidnumber': {u'0': u'100', u'count': u'1'},
#    u'givenname': {u'0': u'Abigail', u'count': u'1'},
#    u'homedirectory': {u'0': u'/users/a/l/alangsne', u'count': u'1'},
#    u'loginshell': {u'0': u'/bin/bash', u'count': u'1'},
#    u'mail': {u'0': u'Abigail.Langsner@uvm.edu', u'count': u'1'},
#    u'mailroutingaddress': {u'0': u'alangsne@msx-po.uvm.edu', u'count': u'1'},
#    u'ou': {u'0': u'Graduate', u'count': u'1'},
#    u'sn': {u'0': u'Langsner', u'count': u'1'},
#    u'telephonenumber': {u'0': u'(603)359-3953', u'count': u'1'},
#    u'uid': {u'0': u'alangsne', u'count': u'1'},
#    u'uidnumber': {u'0': u'287332', u'count': u'1'},
#    u'uvmaltgid': {u'0': u'502', u'count': u'1'},
#    u'uvmalthomedir': {u'0': u'/Users/Customer', u'count': u'1'},
#    u'uvmaltuid': {u'0': u'502', u'count': u'1'},
#    u'uvmeduaffiliation': {u'0': u'Former Student',
#     u'1': u'Current Degree Student',
#     u'count': u'2'},
#    u'uvmedualias': {u'0': u'Abigail.Langsner', u'count': u'1'},
#    u'uvmedubroadcastflag': {u'0': u'a', u'count': u'1'},
#    u'uvmeduprimaryaffiliation': {u'0': u'Current Degree Student',
#     u'count': u'1'},
#    u'uvmedusurname': {u'0': u'Langsner', u'count': u'1'},
#    u'uvmeduuuid': {u'0': u'2970af74-c8a2-11da-96a6-d0e9f2a749f2',
#     u'count': u'1'}},
#   {u'0': u'edupersonprincipalname',
#    u'1': u'uvmedualias',
#    u'10': u'uvmaltuid',
#    u'11': u'uvmaltgid',
#    u'12': u'uvmalthomedir',
#    u'13': u'uid',
#    u'14': u'mail',
#    u'15': u'edupersonentitlement',
#    u'16': u'edupersonprimaryaffiliation',
#    u'17': u'uvmeduprimaryaffiliation',
#    u'18': u'ou',
#    u'19': u'postaladdress',
#    u'2': u'uvmedubroadcastflag',
#    u'20': u'title',
#    u'21': u'uidnumber',
#    u'22': u'gidnumber',
#    u'23': u'gecos',
#    u'24': u'homedirectory',
#    u'25': u'loginshell',
#    u'26': u'mailroutingaddress',
#    u'3': u'uvmeduuuid',
#    u'4': u'edupersonaffiliation',
#    u'5': u'uvmeduaffiliation',
#    u'6': u'cn',
#    u'7': u'givenname',
#    u'8': u'sn',
#    u'9': u'uvmedusurname',
#    u'cn': {u'0': u'Abhilasha Tangada', u'count': u'1'},
#    u'count': u'27',
#    u'dn': u'uid=atangada,ou=People,dc=uvm,dc=edu',
#    u'edupersonaffiliation': {u'0': u'Alum', u'1': u'Faculty', u'count': u'2'},
#    u'edupersonentitlement': {u'0': u'urn:mace:uvm.edu:pgp:encryption-comis',
#     u'1': u'urn:mace:uvm.edu:ets:unix-login',
#     u'2': u'urn:mace:uvm.edu:ets:software-download',
#     u'3': u'urn:mace:uvm.edu:ets:unix-filespace',
#     u'4': u'urn:mace:uvm.edu:ets:email',
#     u'5': u'urn:mace:uvm.edu:ets:ad-login',
#     u'6': u'urn:mace:uvm.edu:ets:ad-filespace',
#     u'7': u'urn:mace:uvm.edu:ets:banner-access',
#     u'count': u'8'},
#    u'edupersonprimaryaffiliation': {u'0': u'Faculty', u'count': u'1'},
#    u'edupersonprincipalname': {u'0': u'atangada@uvm.edu', u'count': u'1'},
#    u'filter_field': u'cn',
#    u'from_filter': u'firstLast',
#    u'gecos': {u'0': u'Abhilasha Tangada', u'count': u'1'},
#    u'gidnumber': {u'0': u'100', u'count': u'1'},
#    u'givenname': {u'0': u'Abhilasha', u'count': u'1'},
#    u'homedirectory': {u'0': u'/users/a/t/atangada', u'count': u'1'},
#    u'loginshell': {u'0': u'/bin/bash', u'count': u'1'},
#    u'mail': {u'0': u'Abhilasha.Tangada@uvm.edu', u'count': u'1'},
#    u'mailroutingaddress': {u'0': u'atangada@msx-po.uvm.edu', u'count': u'1'},
#    u'ou': {u'0': u'Obstetrics Gynecology&amp;Reprod', u'count': u'1'},
#    u'postaladdress': {u'0': u'Danbury Hospital$24 Hospital Ave$Danbury, CT 06810$USA',
#     u'count': u'1'},
#    u'sn': {u'0': u'Tangada', u'count': u'1'},
#    u'title': {u'0': u'Clinical Instructor - Resident', u'count': u'1'},
#    u'uid': {u'0': u'atangada', u'count': u'1'},
#    u'uidnumber': {u'0': u'265856', u'count': u'1'},
#    u'uvmaltgid': {u'0': u'502', u'count': u'1'},
#    u'uvmalthomedir': {u'0': u'/Users/Customer', u'count': u'1'},
#    u'uvmaltuid': {u'0': u'502', u'count': u'1'},
#    u'uvmeduaffiliation': {u'0': u'Former Student',
#     u'1': u'Non-Salaried Faculty',
#     u'count': u'2'},
#    u'uvmedualias': {u'0': u'Abhilasha.Tangada', u'count': u'1'},
#    u'uvmedubroadcastflag': {u'0': u'a', u'count': u'1'},
#    u'uvmeduprimaryaffiliation': {u'0': u'Non-Salaried Faculty',
#     u'count': u'1'},
#    u'uvmedusurname': {u'0': u'Tangada', u'count': u'1'},
#    u'uvmeduuuid': {u'0': u'2fd0e0c8-c8a2-11da-96a6-d0e9f2a749f2',
#     u'count': u'1'}},
#   {u'0': u'edupersonprincipalname',
#    u'1': u'uvmedubroadcastflag',
#    u'10': u'edupersonentitlement',
#    u'11': u'edupersonprimaryaffiliation',
#    u'12': u'uvmeduprimaryaffiliation',
#    u'13': u'ou',
#    u'14': u'title',
#    u'15': u'uidnumber',
#    u'16': u'gidnumber',
#    u'17': u'homedirectory',
#    u'18': u'loginshell',
#    u'19': u'cn',
#    u'2': u'uvmeduuuid',
#    u'20': u'postaladdress',
#    u'21': u'sn',
#    u'22': u'uvmedusurname',
#    u'23': u'gecos',
#    u'24': u'mail',
#    u'25': u'uvmedualias',
#    u'26': u'mailroutingaddress',
#    u'3': u'givenname',
#    u'4': u'uvmaltuid',
#    u'5': u'uvmaltgid',
#    u'6': u'uvmalthomedir',
#    u'7': u'edupersonaffiliation',
#    u'8': u'uvmeduaffiliation',
#    u'9': u'uid',
#    u'cn': {u'0': u'Abigail Rhodes Adler', u'count': u'1'},
#    u'count': u'27',
#    u'dn': u'uid=awoodhea,ou=People,dc=uvm,dc=edu',
#    u'edupersonaffiliation': {u'0': u'Alum', u'1': u'Faculty', u'count': u'2'},
#    u'edupersonentitlement': {u'0': u'urn:mace:uvm.edu:pgp:encryption-comis',
#     u'1': u'urn:mace:uvm.edu:ets:unix-login',
#     u'2': u'urn:mace:uvm.edu:ets:software-download',
#     u'3': u'urn:mace:uvm.edu:ets:unix-filespace',
#     u'4': u'urn:mace:uvm.edu:ets:email',
#     u'5': u'urn:mace:uvm.edu:ets:ad-login',
#     u'6': u'urn:mace:uvm.edu:ets:ad-filespace',
#     u'7': u'urn:mace:uvm.edu:ets:banner-access',
#     u'count': u'8'},
#    u'edupersonprimaryaffiliation': {u'0': u'Faculty', u'count': u'1'},
#    u'edupersonprincipalname': {u'0': u'awoodhea@uvm.edu', u'count': u'1'},
#    u'filter_field': u'cn',
#    u'from_filter': u'firstLast',
#    u'gecos': {u'0': u'Abigail Rhodes Adler', u'count': u'1'},
#    u'gidnumber': {u'0': u'100', u'count': u'1'},
#    u'givenname': {u'0': u'Abigail', u'count': u'1'},
#    u'homedirectory': {u'0': u'/users/a/w/awoodhea', u'count': u'1'},
#    u'loginshell': {u'0': u'/bin/bash', u'count': u'1'},
#    u'mail': {u'0': u'abigail.adler@uvm.edu', u'count': u'1'},
#    u'mailroutingaddress': {u'0': u'awoodhea@msx-po.uvm.edu', u'count': u'1'},
#    u'ou': {u'0': u'Pediatrics', u'count': u'1'},
#    u'postaladdress': {u'0': u'Pediatrics$Smith 5$USA', u'count': u'1'},
#    u'sn': {u'0': u'Adler', u'count': u'1'},
#    u'title': {u'0': u'Assistant Professor', u'count': u'1'},
#    u'uid': {u'0': u'awoodhea', u'count': u'1'},
#    u'uidnumber': {u'0': u'218121', u'count': u'1'},
#    u'uvmaltgid': {u'0': u'502', u'count': u'1'},
#    u'uvmalthomedir': {u'0': u'/Users/Customer', u'count': u'1'},
#    u'uvmaltuid': {u'0': u'502', u'count': u'1'},
#    u'uvmeduaffiliation': {u'0': u'Former Student',
#     u'1': u'12 Month Faculty',
#     u'count': u'2'},
#    u'uvmedualias': {u'0': u'abigail.adler', u'count': u'1'},
#    u'uvmedubroadcastflag': {u'0': u'a', u'count': u'1'},
#    u'uvmeduprimaryaffiliation': {u'0': u'12 Month Faculty', u'count': u'1'},
#    u'uvmedusurname': {u'0': u'Adler', u'count': u'1'},
#    u'uvmeduuuid': {u'0': u'b839c7a0-0802-11db-96db-3017c440dfd5',
#     u'count': u'1'}},
#   {u'0': u'uvmedubroadcastflag',
#    u'1': u'uvmeduuuid',
#    u'10': u'uvmedualias',
#    u'11': u'mail',
#    u'12': u'uidnumber',
#    u'13': u'gidnumber',
#    u'14': u'homedirectory',
#    u'15': u'loginshell',
#    u'16': u'edupersonprincipalname',
#    u'17': u'mailroutingaddress',
#    u'18': u'uvmeduprimaryaffiliation',
#    u'19': u'ou',
#    u'2': u'edupersonaffiliation',
#    u'20': u'cn',
#    u'21': u'sn',
#    u'22': u'uvmedusurname',
#    u'23': u'gecos',
#    u'24': u'edupersonentitlement',
#    u'25': u'telephonenumber',
#    u'3': u'uvmeduaffiliation',
#    u'4': u'givenname',
#    u'5': u'uvmaltuid',
#    u'6': u'uvmaltgid',
#    u'7': u'uvmalthomedir',
#    u'8': u'uid',
#    u'9': u'edupersonprimaryaffiliation',
#    u'cn': {u'0': u'Abigail Elizabeth Harrington', u'count': u'1'},
#    u'count': u'26',
#    u'dn': u'uid=aelogan,ou=People,dc=uvm,dc=edu',
#    u'edupersonaffiliation': {u'0': u'Affiliate',
#     u'1': u'Student',
#     u'count': u'2'},
#    u'edupersonentitlement': {u'0': u'urn:mace:uvm.edu:ets:unix-login',
#     u'1': u'urn:mace:uvm.edu:ets:software-download',
#     u'2': u'urn:mace:uvm.edu:ets:unix-filespace',
#     u'3': u'urn:mace:uvm.edu:ets:email',
#     u'4': u'urn:mace:uvm.edu:ets:ad-login',
#     u'5': u'urn:mace:uvm.edu:ets:banner-access',
#     u'count': u'6'},
#    u'edupersonprimaryaffiliation': {u'0': u'Student', u'count': u'1'},
#    u'edupersonprincipalname': {u'0': u'aelogan@uvm.edu', u'count': u'1'},
#    u'filter_field': u'cn',
#    u'from_filter': u'firstLast',
#    u'gecos': {u'0': u'Abigail Elizabeth Harrington', u'count': u'1'},
#    u'gidnumber': {u'0': u'100', u'count': u'1'},
#    u'givenname': {u'0': u'Abigail', u'count': u'1'},
#    u'homedirectory': {u'0': u'/users/a/e/aelogan', u'count': u'1'},
#    u'loginshell': {u'0': u'/bin/bash', u'count': u'1'},
#    u'mail': {u'0': u'Abigail.Logan@uvm.edu', u'count': u'1'},
#    u'mailroutingaddress': {u'0': u'aelogan@msx-po.uvm.edu', u'count': u'1'},
#    u'ou': {u'0': u'Graduate', u'count': u'1'},
#    u'sn': {u'0': u'Harrington', u'count': u'1'},
#    u'telephonenumber': {u'0': u'(603)359-0090', u'count': u'1'},
#    u'uid': {u'0': u'aelogan', u'count': u'1'},
#    u'uidnumber': {u'0': u'286519', u'count': u'1'},
#    u'uvmaltgid': {u'0': u'502', u'count': u'1'},
#    u'uvmalthomedir': {u'0': u'/Users/Customer', u'count': u'1'},
#    u'uvmaltuid': {u'0': u'502', u'count': u'1'},
#    u'uvmeduaffiliation': {u'0': u'Former Student',
#     u'1': u'Current Degree Student',
#     u'count': u'2'},
#    u'uvmedualias': {u'0': u'Abigail.Logan', u'count': u'1'},
#    u'uvmedubroadcastflag': {u'0': u'a', u'count': u'1'},
#    u'uvmeduprimaryaffiliation': {u'0': u'Current Degree Student',
#     u'count': u'1'},
#    u'uvmedusurname': {u'0': u'Harrington', u'count': u'1'},
#    u'uvmeduuuid': {u'0': u'b7eefd52-b5b2-11db-a587-1daa833df89d',
#     u'count': u'1'}},
#   {u'0': u'edupersonprincipalname',
#    u'1': u'uid',
#    u'10': u'mail',
#    u'11': u'edupersonprimaryaffiliation',
#    u'12': u'uvmeduprimaryaffiliation',
#    u'13': u'edupersonaffiliation',
#    u'14': u'uvmeduaffiliation',
#    u'15': u'cn',
#    u'16': u'givenname',
#    u'17': u'postaladdress',
#    u'18': u'sn',
#    u'19': u'title',
#    u'2': u'uvmedubroadcastflag',
#    u'20': u'uvmedusurname',
#    u'21': u'uvmaltuid',
#    u'22': u'uvmaltgid',
#    u'23': u'uvmalthomedir',
#    u'24': u'edupersonentitlement',
#    u'25': u'ou',
#    u'26': u'mailroutingaddress',
#    u'3': u'uvmeduuuid',
#    u'4': u'uidnumber',
#    u'5': u'gidnumber',
#    u'6': u'homedirectory',
#    u'7': u'loginshell',
#    u'8': u'gecos',
#    u'9': u'uvmedualias',
#    u'cn': {u'0': u'Abigail I. Sperry', u'count': u'1'},
#    u'count': u'27',
#    u'dn': u'uid=aisperry,ou=People,dc=uvm,dc=edu',
#    u'edupersonaffiliation': {u'0': u'Faculty',
#     u'1': u'Affiliate',
#     u'2': u'Alum',
#     u'count': u'3'},
#    u'edupersonentitlement': {u'0': u'urn:mace:uvm.edu:pgp:encryption',
#     u'1': u'urn:mace:uvm.edu:ets:unix-login',
#     u'2': u'urn:mace:uvm.edu:ets:software-download',
#     u'3': u'urn:mace:uvm.edu:ets:unix-filespace',
#     u'4': u'urn:mace:uvm.edu:ets:email',
#     u'5': u'urn:mace:uvm.edu:ets:ad-login',
#     u'6': u'urn:mace:uvm.edu:ets:ad-filespace',
#     u'7': u'urn:mace:uvm.edu:ets:banner-access',
#     u'count': u'8'},
#    u'edupersonprimaryaffiliation': {u'0': u'Faculty', u'count': u'1'},
#    u'edupersonprincipalname': {u'0': u'aisperry@uvm.edu', u'count': u'1'},
#    u'filter_field': u'cn',
#    u'from_filter': u'firstLast',
#    u'gecos': {u'0': u'Abigail I. Sperry', u'count': u'1'},
#    u'gidnumber': {u'0': u'100', u'count': u'1'},
#    u'givenname': {u'0': u'Abigail', u'count': u'1'},
#    u'homedirectory': {u'0': u'/users/a/i/aisperry', u'count': u'1'},
#    u'loginshell': {u'0': u'/bin/bash', u'count': u'1'},
#    u'mail': {u'0': u'Abigail.Sperry@uvm.edu', u'count': u'1'},
#    u'mailroutingaddress': {u'0': u'aisperry@msx-po.uvm.edu', u'count': u'1'},
#    u'ou': {u'0': u'Romance Languages&amp;Linguistics', u'count': u'1'},
#    u'postaladdress': {u'0': u'Romance Languages Dept.$Waterman Bldg, Rm 304$USA',
#     u'count': u'1'},
#    u'sn': {u'0': u'Sperry', u'count': u'1'},
#    u'title': {u'0': u'Lecturer', u'count': u'1'},
#    u'uid': {u'0': u'aisperry', u'count': u'1'},
#    u'uidnumber': {u'0': u'74854', u'count': u'1'},
#    u'uvmaltgid': {u'0': u'502', u'count': u'1'},
#    u'uvmalthomedir': {u'0': u'/Users/Customer', u'count': u'1'},
#    u'uvmaltuid': {u'0': u'502', u'count': u'1'},
#    u'uvmeduaffiliation': {u'0': u'9 Month Faculty',
#     u'1': u'Banner Course Assignment',
#     u'2': u'Former Student',
#     u'count': u'3'},
#    u'uvmedualias': {u'0': u'Abigail.Sperry', u'count': u'1'},
#    u'uvmedubroadcastflag': {u'0': u'a', u'count': u'1'},
#    u'uvmeduprimaryaffiliation': {u'0': u'9 Month Faculty', u'count': u'1'},
#    u'uvmedusurname': {u'0': u'Sperry', u'count': u'1'},
#    u'uvmeduuuid': {u'0': u'3b7c017c-39ae-11dc-881f-4b09843df89d',
#     u'count': u'1'}},
#   {u'0': u'givenname',
#    u'1': u'sn',
#    u'10': u'mail',
#    u'11': u'edupersonentitlement',
#    u'12': u'edupersonprimaryaffiliation',
#    u'13': u'uvmeduprimaryaffiliation',
#    u'14': u'edupersonaffiliation',
#    u'15': u'uvmeduaffiliation',
#    u'16': u'ou',
#    u'17': u'cn',
#    u'18': u'postaladdress',
#    u'19': u'title',
#    u'2': u'uid',
#    u'20': u'uidnumber',
#    u'21': u'gidnumber',
#    u'22': u'gecos',
#    u'23': u'homedirectory',
#    u'24': u'loginshell',
#    u'25': u'edupersonprincipalname',
#    u'26': u'mailroutingaddress',
#    u'3': u'uvmaltgid',
#    u'4': u'uvmalthomedir',
#    u'5': u'uvmaltuid',
#    u'6': u'uvmedualias',
#    u'7': u'uvmedubroadcastflag',
#    u'8': u'uvmeduuuid',
#    u'9': u'uvmedusurname',
#    u'cn': {u'0': u'Abigail J Pastor', u'count': u'1'},
#    u'count': u'27',
#    u'dn': u'uid=apastor,ou=People,dc=uvm,dc=edu',
#    u'edupersonaffiliation': {u'0': u'Employee', u'count': u'1'},
#    u'edupersonentitlement': {u'0': u'urn:mace:uvm.edu:pgp:encryption',
#     u'1': u'urn:mace:uvm.edu:ets:unix-login',
#     u'2': u'urn:mace:uvm.edu:ets:software-download',
#     u'3': u'urn:mace:uvm.edu:ets:unix-filespace',
#     u'4': u'urn:mace:uvm.edu:ets:email',
#     u'5': u'urn:mace:uvm.edu:ets:ad-login',
#     u'6': u'urn:mace:uvm.edu:ets:ad-filespace',
#     u'count': u'7'},
#    u'edupersonprimaryaffiliation': {u'0': u'Employee', u'count': u'1'},
#    u'edupersonprincipalname': {u'0': u'apastor@uvm.edu', u'count': u'1'},
#    u'filter_field': u'cn',
#    u'from_filter': u'firstLast',
#    u'gecos': {u'0': u'Abigail J Pastor', u'count': u'1'},
#    u'gidnumber': {u'0': u'100', u'count': u'1'},
#    u'givenname': {u'0': u'Abigail', u'count': u'1'},
#    u'homedirectory': {u'0': u'/users/a/p/apastor', u'count': u'1'},
#    u'loginshell': {u'0': u'/bin/bash', u'count': u'1'},
#    u'mail': {u'0': u'Abigail.Pastor@uvm.edu', u'count': u'1'},
#    u'mailroutingaddress': {u'0': u'apastor@msx-po.uvm.edu', u'count': u'1'},
#    u'ou': {u'0': u'Center for Academic Success', u'count': u'1'},
#    u'postaladdress': {u'0': u'Living/Learning$CFAS/SAS, A131$USA',
#     u'count': u'1'},
#    u'sn': {u'0': u'Pastor', u'count': u'1'},
#    u'title': {u'0': u'Temporary Hourly Employee', u'count': u'1'},
#    u'uid': {u'0': u'apastor', u'count': u'1'},
#    u'uidnumber': {u'0': u'308557', u'count': u'1'},
#    u'uvmaltgid': {u'0': u'502', u'count': u'1'},
#    u'uvmalthomedir': {u'0': u'/Users/Customer', u'count': u'1'},
#    u'uvmaltuid': {u'0': u'502', u'count': u'1'},
#    u'uvmeduaffiliation': {u'0': u'Temporary', u'count': u'1'},
#    u'uvmedualias': {u'0': u'Abigail.Pastor', u'count': u'1'},
#    u'uvmedubroadcastflag': {u'0': u'a', u'count': u'1'},
#    u'uvmeduprimaryaffiliation': {u'0': u'Temporary', u'count': u'1'},
#    u'uvmedusurname': {u'0': u'Pastor', u'count': u'1'},
#    u'uvmeduuuid': {u'0': u'a7c73f9e-e43b-11dc-a58e-7ace833df89d',
#     u'count': u'1'}},
#   {u'0': u'edupersonprincipalname',
#    u'1': u'uid',
#    u'10': u'givenname',
#    u'11': u'uvmaltuid',
#    u'12': u'uvmaltgid',
#    u'13': u'uvmalthomedir',
#    u'14': u'edupersonentitlement',
#    u'15': u'sn',
#    u'16': u'uvmedusurname',
#    u'17': u'mail',
#    u'18': u'uvmedualias',
#    u'19': u'edupersonprimaryaffiliation',
#    u'2': u'uvmedubroadcastflag',
#    u'20': u'uvmeduprimaryaffiliation',
#    u'21': u'ou',
#    u'22': u'title',
#    u'23': u'cn',
#    u'24': u'postaladdress',
#    u'25': u'gecos',
#    u'26': u'uvmeduofficephone',
#    u'27': u'uvmeduofficeaddress',
#    u'28': u'mailroutingaddress',
#    u'29': u'telephonenumber',
#    u'3': u'uvmeduuuid',
#    u'4': u'uidnumber',
#    u'5': u'gidnumber',
#    u'6': u'homedirectory',
#    u'7': u'loginshell',
#    u'8': u'edupersonaffiliation',
#    u'9': u'uvmeduaffiliation',
#    u'cn': {u'0': u'Abbie Chapman Johnson', u'count': u'1'},
#    u'count': u'30',
#    u'dn': u'uid=acchapma,ou=People,dc=uvm,dc=edu',
#    u'edupersonaffiliation': {u'0': u'Employee', u'1': u'Alum', u'count': u'2'},
#    u'edupersonentitlement': {u'0': u'urn:mace:uvm.edu:pgp:encryption',
#     u'1': u'urn:mace:uvm.edu:vpn:basic',
#     u'2': u'urn:mace:uvm.edu:ets:unix-login',
#     u'3': u'urn:mace:uvm.edu:ets:software-download',
#     u'4': u'urn:mace:uvm.edu:ets:unix-filespace',
#     u'5': u'urn:mace:uvm.edu:ets:email',
#     u'6': u'urn:mace:uvm.edu:ets:ad-login',
#     u'7': u'urn:mace:uvm.edu:ets:ad-filespace',
#     u'8': u'urn:mace:uvm.edu:ets:banner-access',
#     u'9': u'urn:mace:uvm.edu:ets:lifetime-email',
#     u'count': u'10'},
#    u'edupersonprimaryaffiliation': {u'0': u'Employee', u'count': u'1'},
#    u'edupersonprincipalname': {u'0': u'acchapma@uvm.edu', u'count': u'1'},
#    u'filter_field': u'cn',
#    u'from_filter': u'firstLast',
#    u'gecos': {u'0': u'Abbie Chapman Johnson', u'count': u'1'},
#    u'gidnumber': {u'0': u'100', u'count': u'1'},
#    u'givenname': {u'0': u'Abbie', u'count': u'1'},
#    u'homedirectory': {u'0': u'/users/a/c/acchapma', u'count': u'1'},
#    u'loginshell': {u'0': u'/bin/bash', u'count': u'1'},
#    u'mail': {u'0': u'abbie.johnson@uvm.edu', u'count': u'1'},
#    u'mailroutingaddress': {u'0': u'acchapma@msx-po.uvm.edu', u'count': u'1'},
#    u'ou': {u'0': u'Neurological Sciences', u'count': u'1'},
#    u'postaladdress': {u'0': u'Neurological Sciences$HSRF 433$USA',
#     u'count': u'1'},
#    u'sn': {u'0': u'Johnson', u'count': u'1'},
#    u'telephonenumber': {u'0': u'+1 802-656-8436', u'count': u'1'},
#    u'title': {u'0': u'Post Doctoral Associate', u'count': u'1'},
#    u'uid': {u'0': u'acchapma', u'count': u'1'},
#    u'uidnumber': {u'0': u'108491', u'count': u'1'},
#    u'uvmaltgid': {u'0': u'502', u'count': u'1'},
#    u'uvmalthomedir': {u'0': u'/Users/Customer', u'count': u'1'},
#    u'uvmaltuid': {u'0': u'502', u'count': u'1'},
#    u'uvmeduaffiliation': {u'0': u'Former Student',
#     u'1': u'12 Month Post Doc Assoc',
#     u'count': u'2'},
#    u'uvmedualias': {u'0': u'abbie.johnson', u'count': u'1'},
#    u'uvmedubroadcastflag': {u'0': u'a', u'count': u'1'},
#    u'uvmeduofficeaddress': {u'0': u'HSRF 416', u'count': u'1'},
#    u'uvmeduofficephone': {u'0': u'802-656-4231', u'count': u'1'},
#    u'uvmeduprimaryaffiliation': {u'0': u'12 Month Post Doc Assoc',
#     u'count': u'1'},
#    u'uvmedusurname': {u'0': u'Johnson', u'count': u'1'},
#    u'uvmeduuuid': {u'0': u'0a965c92-ad66-11dd-b0f1-d0d3833df89d',
#     u'count': u'1'}},
#   {u'0': u'uvmeduuuid',
#    u'1': u'uvmedubroadcastflag',
#    u'10': u'edupersonprimaryaffiliation',
#    u'11': u'uvmeduprimaryaffiliation',
#    u'12': u'ou',
#    u'13': u'postaladdress',
#    u'14': u'sn',
#    u'15': u'uvmedusurname',
#    u'16': u'title',
#    u'17': u'edupersonprincipalname',
#    u'18': u'uid',
#    u'19': u'uidnumber',
#    u'2': u'edupersonaffiliation',
#    u'20': u'gidnumber',
#    u'21': u'gecos',
#    u'22': u'homedirectory',
#    u'23': u'loginshell',
#    u'24': u'mail',
#    u'25': u'cn',
#    u'26': u'mailroutingaddress',
#    u'27': u'telephonenumber',
#    u'3': u'uvmeduaffiliation',
#    u'4': u'givenname',
#    u'5': u'uvmaltuid',
#    u'6': u'uvmaltgid',
#    u'7': u'uvmalthomedir',
#    u'8': u'uvmedualias',
#    u'9': u'edupersonentitlement',
#    u'cn': {u'0': u'Abby G Kelley', u'count': u'1'},
#    u'count': u'28',
#    u'dn': u'uid=agkelley,ou=People,dc=uvm,dc=edu',
#    u'edupersonaffiliation': {u'0': u'Alum', u'1': u'Staff', u'count': u'2'},
#    u'edupersonentitlement': {u'0': u'urn:mace:uvm.edu:pgp:encryption',
#     u'1': u'urn:mace:uvm.edu:ets:unix-login',
#     u'2': u'urn:mace:uvm.edu:ets:software-download',
#     u'3': u'urn:mace:uvm.edu:ets:unix-filespace',
#     u'4': u'urn:mace:uvm.edu:ets:email',
#     u'5': u'urn:mace:uvm.edu:ets:ad-login',
#     u'6': u'urn:mace:uvm.edu:ets:ad-filespace',
#     u'7': u'urn:mace:uvm.edu:ets:banner-access',
#     u'count': u'8'},
#    u'edupersonprimaryaffiliation': {u'0': u'Staff', u'count': u'1'},
#    u'edupersonprincipalname': {u'0': u'agkelley@uvm.edu', u'count': u'1'},
#    u'filter_field': u'cn',
#    u'from_filter': u'firstLast',
#    u'gecos': {u'0': u'Abby G Kelley', u'count': u'1'},
#    u'gidnumber': {u'0': u'100', u'count': u'1'},
#    u'givenname': {u'0': u'Abby', u'count': u'1'},
#    u'homedirectory': {u'0': u'/users/a/g/agkelley', u'count': u'1'},
#    u'loginshell': {u'0': u'/bin/bash', u'count': u'1'},
#    u'mail': {u'0': u'Abby.Kelley@uvm.edu', u'count': u'1'},
#    u'mailroutingaddress': {u'0': u'agkelley@msx-po.uvm.edu', u'count': u'1'},
#    u'ou': {u'0': u'Residential Life', u'count': u'1'},
#    u'postaladdress': {u'0': u'Residential Life$Robinson Hall$USA',
#     u'count': u'1'},
#    u'sn': {u'0': u'Kelley', u'count': u'1'},
#    u'telephonenumber': {u'0': u'+1 802-656-4155', u'count': u'1'},
#    u'title': {u'0': u'Office Manager', u'count': u'1'},
#    u'uid': {u'0': u'agkelley', u'count': u'1'},
#    u'uidnumber': {u'0': u'196082', u'count': u'1'},
#    u'uvmaltgid': {u'0': u'502', u'count': u'1'},
#    u'uvmalthomedir': {u'0': u'/Users/Customer', u'count': u'1'},
#    u'uvmaltuid': {u'0': u'502', u'count': u'1'},
#    u'uvmeduaffiliation': {u'0': u'Former Student',
#     u'1': u'10 Month Staff',
#     u'count': u'2'},
#    u'uvmedualias': {u'0': u'Abby.Kelley', u'count': u'1'},
#    u'uvmedubroadcastflag': {u'0': u'a', u'count': u'1'},
#    u'uvmeduprimaryaffiliation': {u'0': u'10 Month Staff', u'count': u'1'},
#    u'uvmedusurname': {u'0': u'Kelley', u'count': u'1'},
#    u'uvmeduuuid': {u'0': u'e24f1e7e-6117-11df-b84f-9fa9833df89d',
#     u'count': u'1'}},
#   {u'0': u'uvmeduuuid',
#    u'1': u'uvmedubroadcastflag',
#    u'10': u'uvmeduaffiliation',
#    u'11': u'uvmeduaccountdisabledtime',
#    u'12': u'edupersonentitlement',
#    u'13': u'uid',
#    u'14': u'edupersonprimaryaffiliation',
#    u'15': u'uvmeduprimaryaffiliation',
#    u'16': u'ou',
#    u'17': u'uvmedualias',
#    u'18': u'mail',
#    u'19': u'uidnumber',
#    u'2': u'cn',
#    u'20': u'gidnumber',
#    u'21': u'gecos',
#    u'22': u'homedirectory',
#    u'23': u'loginshell',
#    u'24': u'edupersonprincipalname',
#    u'25': u'mailroutingaddress',
#    u'3': u'givenname',
#    u'4': u'sn',
#    u'5': u'uvmedusurname',
#    u'6': u'uvmaltuid',
#    u'7': u'uvmaltgid',
#    u'8': u'uvmalthomedir',
#    u'9': u'edupersonaffiliation',
#    u'cn': {u'0': u'Abbi Brooke Bailey', u'count': u'1'},
#    u'count': u'26',
#    u'dn': u'uid=abbailey,ou=People,dc=uvm,dc=edu',
#    u'edupersonaffiliation': {u'0': u'Alum', u'1': u'Student', u'count': u'2'},
#    u'edupersonentitlement': {u'0': u'urn:mace:uvm.edu:ets:banner-access',
#     u'1': u'urn:mace:uvm.edu:ets:unix-login',
#     u'2': u'urn:mace:uvm.edu:ets:software-download',
#     u'3': u'urn:mace:uvm.edu:ets:unix-filespace',
#     u'4': u'urn:mace:uvm.edu:ets:email',
#     u'5': u'urn:mace:uvm.edu:ets:ad-login',
#     u'count': u'6'},
#    u'edupersonprimaryaffiliation': {u'0': u'Student', u'count': u'1'},
#    u'edupersonprincipalname': {u'0': u'abbailey@uvm.edu', u'count': u'1'},
#    u'filter_field': u'cn',
#    u'from_filter': u'firstLast',
#    u'gecos': {u'0': u'Abbi Brooke Bailey', u'count': u'1'},
#    u'gidnumber': {u'0': u'100', u'count': u'1'},
#    u'givenname': {u'0': u'Abbi', u'count': u'1'},
#    u'homedirectory': {u'0': u'/users/a/b/abbailey', u'count': u'1'},
#    u'loginshell': {u'0': u'/bin/bash', u'count': u'1'},
#    u'mail': {u'0': u'Abbi.Bailey@uvm.edu', u'count': u'1'},
#    u'mailroutingaddress': {u'0': u'abbailey@msx-po.uvm.edu', u'count': u'1'},
#    u'ou': {u'0': u'Admitted', u'count': u'1'},
#    u'sn': {u'0': u'Bailey', u'count': u'1'},
#    u'uid': {u'0': u'abbailey', u'count': u'1'},
#    u'uidnumber': {u'0': u'327493', u'count': u'1'},
#    u'uvmaltgid': {u'0': u'502', u'count': u'1'},
# ...
#    u'13': u'uidnumber',
#    u'14': u'gidnumber',
#    u'15': u'homedirectory',
#    u'16': u'loginshell',
#    u'17': u'edupersonprincipalname',
#    u'18': u'mailroutingaddress',
#    u'19': u'edupersonentitlement',
#    u'2': u'uvmedubroadcastflag',
#    u'20': u'uvmeduaffiliation',
#    u'21': u'gecos',
#    u'22': u'edupersonprimaryaffiliation',
#    u'23': u'uvmeduprimaryaffiliation',
#    u'24': u'ou',
#    u'3': u'mail',
#    u'4': u'uid',
#    u'5': u'edupersonaffiliation',
#    u'6': u'cn',
#    u'7': u'givenname',
#    u'8': u'sn',
#    u'9': u'uvmedusurname',
#    u'cn': {u'0': u'Abby Eugenia Steinhauer', u'count': u'1'},
#    u'count': u'25',
#    u'dn': u'uid=aesteinh,ou=People,dc=uvm,dc=edu',
#    u'edupersonaffiliation': {u'0': u'Student',
#     u'1': u'Affiliate',
#     u'count': u'2'},
#    u'edupersonentitlement': {u'0': u'urn:mace:uvm.edu:ets:unix-login',
#     u'1': u'urn:mace:uvm.edu:ets:software-download',
#     u'2': u'urn:mace:uvm.edu:ets:unix-filespace',
#     u'3': u'urn:mace:uvm.edu:ets:email',
#     u'4': u'urn:mace:uvm.edu:ets:ad-login',
#     u'5': u'urn:mace:uvm.edu:ets:banner-access',
#     u'count': u'6'},
#    u'edupersonprimaryaffiliation': {u'0': u'Student', u'count': u'1'},
#    u'edupersonprincipalname': {u'0': u'aesteinh@uvm.edu', u'count': u'1'},
#    u'filter_field': u'cn',
#    u'from_filter': u'cn',
#    u'gecos': {u'0': u'Abby Eugenia Steinhauer', u'count': u'1'},
#    u'gidnumber': {u'0': u'100', u'count': u'1'},
#    u'givenname': {u'0': u'Abby', u'count': u'1'},
#    u'homedirectory': {u'0': u'/users/a/e/aesteinh', u'count': u'1'},
#    u'loginshell': {u'0': u'/bin/bash', u'count': u'1'},
#    u'mail': {u'0': u'Abigail.Steinhauer@uvm.edu', u'count': u'1'},
#    u'mailroutingaddress': {u'0': u'aesteinh@msx-po.uvm.edu', u'count': u'1'},
#    u'ou': {u'0': u'Sophomore', u'count': u'1'},
#    u'sn': {u'0': u'Steinhauer', u'count': u'1'},
#    u'uid': {u'0': u'aesteinh', u'count': u'1'},
#    u'uidnumber': {u'0': u'288872', u'count': u'1'},
#    u'uvmaltgid': {u'0': u'502', u'count': u'1'},
#    u'uvmalthomedir': {u'0': u'/Users/Customer', u'count': u'1'},
#    u'uvmaltuid': {u'0': u'502', u'count': u'1'},
#    u'uvmeduaffiliation': {u'0': u'Current Degree Student',
#     u'1': u'Former Student',
#     u'count': u'2'},
#    u'uvmedualias': {u'0': u'Abigail.Steinhauer', u'count': u'1'},
#    u'uvmedubroadcastflag': {u'0': u'a', u'count': u'1'},
#    u'uvmeduprimaryaffiliation': {u'0': u'Current Degree Student',
#     u'count': u'1'},
#    u'uvmedusurname': {u'0': u'Steinhauer', u'count': u'1'},
#    u'uvmeduuuid': {u'0': u'11f62334-9fc8-11e6-a066-bf37cefaea91',
#     u'count': u'1'}},
#   {u'0': u'uvmeduuuid',
#    u'1': u'uvmedualias',
#    u'10': u'uvmaltuid',
#    u'11': u'uvmaltgid',
#    u'12': u'uvmalthomedir',
#    u'13': u'uidnumber',
#    u'14': u'gidnumber',
#    u'15': u'homedirectory',
#    u'16': u'loginshell',
#    u'17': u'edupersonprincipalname',
#    u'18': u'mailroutingaddress',
#    u'19': u'edupersonentitlement',
#    u'2': u'uvmedubroadcastflag',
#    u'20': u'uvmeduaffiliation',
#    u'21': u'gecos',
#    u'22': u'edupersonprimaryaffiliation',
#    u'23': u'uvmeduprimaryaffiliation',
#    u'24': u'ou',
#    u'3': u'mail',
#    u'4': u'uid',
#    u'5': u'edupersonaffiliation',
#    u'6': u'cn',
#    u'7': u'givenname',
#    u'8': u'sn',
#    u'9': u'uvmedusurname',
#    u'cn': {u'0': u'Abby Elizabeth Munterich', u'count': u'1'},
#    u'count': u'25',
#    u'dn': u'uid=amunteri,ou=People,dc=uvm,dc=edu',
#    u'edupersonaffiliation': {u'0': u'Student',
#     u'1': u'Affiliate',
#     u'count': u'2'},
#    u'edupersonentitlement': {u'0': u'urn:mace:uvm.edu:ets:unix-login',
#     u'1': u'urn:mace:uvm.edu:ets:software-download',
#     u'2': u'urn:mace:uvm.edu:ets:unix-filespace',
#     u'3': u'urn:mace:uvm.edu:ets:email',
#     u'4': u'urn:mace:uvm.edu:ets:ad-login',
#     u'5': u'urn:mace:uvm.edu:ets:banner-access',
#     u'count': u'6'},
#    u'edupersonprimaryaffiliation': {u'0': u'Student', u'count': u'1'},
#    u'edupersonprincipalname': {u'0': u'amunteri@uvm.edu', u'count': u'1'},
#    u'filter_field': u'cn',
#    u'from_filter': u'cn',
#    u'gecos': {u'0': u'Abby Elizabeth Munterich', u'count': u'1'},
#    u'gidnumber': {u'0': u'100', u'count': u'1'},
#    u'givenname': {u'0': u'Abby', u'count': u'1'},
#    u'homedirectory': {u'0': u'/users/a/m/amunteri', u'count': u'1'},
#    u'loginshell': {u'0': u'/bin/bash', u'count': u'1'},
#    u'mail': {u'0': u'Abby.Munterich@uvm.edu', u'count': u'1'},
#    u'mailroutingaddress': {u'0': u'amunteri@msx-po.uvm.edu', u'count': u'1'},
#    u'ou': {u'0': u'Junior', u'count': u'1'},
#    u'sn': {u'0': u'Munterich', u'count': u'1'},
#    u'uid': {u'0': u'amunteri', u'count': u'1'},
#    u'uidnumber': {u'0': u'288962', u'count': u'1'},
#    u'uvmaltgid': {u'0': u'502', u'count': u'1'},
#    u'uvmalthomedir': {u'0': u'/Users/Customer', u'count': u'1'},
#    u'uvmaltuid': {u'0': u'502', u'count': u'1'},
#    u'uvmeduaffiliation': {u'0': u'Current Degree Student',
#     u'1': u'Former Student',
#     u'count': u'2'},
#    u'uvmedualias': {u'0': u'Abby.Munterich', u'count': u'1'},
#    u'uvmedubroadcastflag': {u'0': u'a', u'count': u'1'},
#    u'uvmeduprimaryaffiliation': {u'0': u'Current Degree Student',
#     u'count': u'1'},
#    u'uvmedusurname': {u'0': u'Munterich', u'count': u'1'},
#    u'uvmeduuuid': {u'0': u'15d7b184-9fc8-11e6-a066-bf37cefaea91',
#     u'count': u'1'}},
#   {u'0': u'uvmeduuuid',
#    u'1': u'uvmedualias',
#    u'10': u'uvmaltuid',
#    u'11': u'uvmaltgid',
#    u'12': u'uvmalthomedir',
#    u'13': u'uidnumber',
#    u'14': u'gidnumber',
#    u'15': u'homedirectory',
#    u'16': u'loginshell',
#    u'17': u'edupersonprincipalname',
#    u'18': u'mailroutingaddress',
#    u'19': u'edupersonentitlement',
#    u'2': u'uvmedubroadcastflag',
#    u'20': u'uvmeduaffiliation',
#    u'21': u'gecos',
#    u'22': u'edupersonprimaryaffiliation',
#    u'23': u'uvmeduprimaryaffiliation',
#    u'24': u'ou',
#    u'3': u'mail',
#    u'4': u'uid',
#    u'5': u'edupersonaffiliation',
#    u'6': u'cn',
#    u'7': u'givenname',
#    u'8': u'sn',
#    u'9': u'uvmedusurname',
#    u'cn': {u'0': u'Abby Goldman', u'count': u'1'},
#    u'count': u'25',
#    u'dn': u'uid=agoldma3,ou=People,dc=uvm,dc=edu',
#    u'edupersonaffiliation': {u'0': u'Student',
#     u'1': u'Affiliate',
#     u'count': u'2'},
#    u'edupersonentitlement': {u'0': u'urn:mace:uvm.edu:ets:unix-login',
#     u'1': u'urn:mace:uvm.edu:ets:software-download',
#     u'2': u'urn:mace:uvm.edu:ets:unix-filespace',
#     u'3': u'urn:mace:uvm.edu:ets:email',
#     u'4': u'urn:mace:uvm.edu:ets:ad-login',
#     u'5': u'urn:mace:uvm.edu:ets:banner-access',
#     u'count': u'6'},
#    u'edupersonprimaryaffiliation': {u'0': u'Student', u'count': u'1'},
#    u'edupersonprincipalname': {u'0': u'agoldma3@uvm.edu', u'count': u'1'},
#    u'filter_field': u'cn',
#    u'from_filter': u'cn',
#    u'gecos': {u'0': u'Abby Goldman', u'count': u'1'},
#    u'gidnumber': {u'0': u'100', u'count': u'1'},
#    u'givenname': {u'0': u'Abby', u'count': u'1'},
#    u'homedirectory': {u'0': u'/users/a/g/agoldma3', u'count': u'1'},
#    u'loginshell': {u'0': u'/bin/bash', u'count': u'1'},
#    u'mail': {u'0': u'Abby.Goldman@uvm.edu', u'count': u'1'},
#    u'mailroutingaddress': {u'0': u'agoldma3@msx-po.uvm.edu', u'count': u'1'},
#    u'ou': {u'0': u'Sophomore', u'count': u'1'},
#    u'sn': {u'0': u'Goldman', u'count': u'1'},
#    u'uid': {u'0': u'agoldma3', u'count': u'1'},
#    u'uidnumber': {u'0': u'289406', u'count': u'1'},
#    u'uvmaltgid': {u'0': u'502', u'count': u'1'},
#    u'uvmalthomedir': {u'0': u'/Users/Customer', u'count': u'1'},
#    u'uvmaltuid': {u'0': u'502', u'count': u'1'},
#    u'uvmeduaffiliation': {u'0': u'Current Degree Student',
#     u'1': u'Former Student',
#     u'count': u'2'},
#    u'uvmedualias': {u'0': u'Abby.Goldman', u'count': u'1'},
#    u'uvmedubroadcastflag': {u'0': u'a', u'count': u'1'},
#    u'uvmeduprimaryaffiliation': {u'0': u'Current Degree Student',
#     u'count': u'1'},
#    u'uvmedusurname': {u'0': u'Goldman', u'count': u'1'},
#    u'uvmeduuuid': {u'0': u'76d05bec-a15a-11e6-84c3-d244cefaea91',
#     u'count': u'1'}},
#   {u'0': u'edupersonprincipalname',
#    u'1': u'gidnumber',
#    u'10': u'uvmeduhours',
#    u'11': u'labeleduri',
#    u'12': u'uvmedubroadcastflag',
#    u'13': u'givenname',
#    u'14': u'sn',
#    u'15': u'uvmedusurname',
#    u'16': u'uvmaltuid',
#    u'17': u'uvmaltgid',
#    u'18': u'uvmalthomedir',
#    u'19': u'loginshell',
#    u'2': u'homedirectory',
#    u'20': u'uvmedualias',
#    u'21': u'mail',
#    u'22': u'uvmeduprimaryaffiliation',
#    u'23': u'uvmeduaffiliation',
#    u'24': u'ou',
#    u'25': u'cn',
#    u'26': u'title',
#    u'27': u'gecos',
#    u'28': u'mailroutingaddress',
#    u'3': u'uidnumber',
#    u'4': u'uid',
#    u'5': u'uvmeduuuid',
#    u'6': u'edupersonnickname',
#    u'7': u'uvmeduofficeaddress',
#    u'8': u'uvmeduofficephone',
#    u'9': u'facsimiletelephonenumber',
#    u'cn': {u'0': u'Saiyid Rizvi', u'count': u'1'},
#    u'count': u'29',
#    u'dn': u'uid=srizvi,ou=People,dc=uvm,dc=edu',
#    u'edupersonnickname': {u'0': u'Abu', u'count': u'1'},
#    u'edupersonprincipalname': {u'0': u'srizvi@uvm.edu', u'count': u'1'},
#    u'facsimiletelephonenumber': {u'0': u'802/656-9009', u'count': u'1'},
#    u'filter_field': u'cn',
#    u'from_filter': u'displayName',
#    u'gecos': {u'0': u'Saiyid Rizvi', u'count': u'1'},
#    u'gidnumber': {u'0': u'100', u'count': u'1'},
#    u'givenname': {u'0': u'Saiyid', u'count': u'1'},
#    u'homedirectory': {u'0': u'/users/s/r/srizvi', u'count': u'1'},
#    u'labeleduri': {u'0': u'www.uvm.edu/~srizvi', u'count': u'1'},
#    u'loginshell': {u'0': u'/bin/bash', u'count': u'1'},
#    u'mail': {u'0': u'Saiyid.Rizvi@uvm.edu', u'count': u'1'},
#    u'mailroutingaddress': {u'0': u'srizvi@msx-po.uvm.edu', u'count': u'1'},
#    u'ou': {u'0': u'Emeriti Faculty', u'count': u'1'},
#    u'sn': {u'0': u'Rizvi', u'count': u'1'},
#    u'title': {u'0': u'Emeriti Faculty', u'count': u'1'},
#    u'uid': {u'0': u'srizvi', u'count': u'1'},
#    u'uidnumber': {u'0': u'5484', u'count': u'1'},
#    u'uvmaltgid': {u'0': u'502', u'count': u'1'},
#    u'uvmalthomedir': {u'0': u'/Users/Customer', u'count': u'1'},
#    u'uvmaltuid': {u'0': u'502', u'count': u'1'},
#    u'uvmeduaffiliation': {u'0': u'Emeriti Faculty', u'count': u'1'},
#    u'uvmedualias': {u'0': u'Saiyid.Rizvi', u'count': u'1'},
#    u'uvmedubroadcastflag': {u'0': u'a', u'count': u'1'},
#    u'uvmeduhours': {u'0': u'To make appts, contact Tina Griffis (cgriffis@uvm.edu or 656-9100)',
#     u'count': u'1'},
#    u'uvmeduofficeaddress': {u'0': u'Honors College, 50 University Heights',
#     u'count': u'1'},
#    u'uvmeduofficephone': {u'0': u' 802/656-9102 ', u'count': u'1'},
#    u'uvmeduprimaryaffiliation': {u'0': u'Emeriti Faculty', u'count': u'1'},
#    u'uvmedusurname': {u'0': u'Rizvi', u'count': u'1'},
#    u'uvmeduuuid': {u'0': u'1007e944-c8a2-11da-96a6-d0e9f2a749f2',
#     u'count': u'1'}},
#   {u'0': u'sn',
#    u'1': u'uvmeduaffiliation',
#    u'10': u'mail',
#    u'11': u'edupersonprincipalname',
#    u'12': u'cn',
#    u'13': u'uvmeduuuid',
#    u'14': u'uidnumber',
#    u'15': u'gidnumber',
#    u'16': u'gecos',
#    u'17': u'homedirectory',
#    u'18': u'loginshell',
#    u'19': u'uvmedusurname',
#    u'2': u'uvmeduprimaryaffiliation',
#    u'20': u'edupersonnickname',
#    u'21': u'uvmeduofficeaddress',
#    u'22': u'uvmeduofficephone',
#    u'23': u'facsimiletelephonenumber',
#    u'24': u'uvmedubroadcastflag',
#    u'25': u'mailroutingaddress',
#    u'3': u'edupersonaffiliation',
#    u'4': u'edupersonprimaryaffiliation',
#    u'5': u'uvmaltuid',
#    u'6': u'uvmaltgid',
#    u'7': u'uvmalthomedir',
#    u'8': u'uvmedualias',
#    u'9': u'uid',
#    u'cn': {u'0': u'Administrative Business Service-Center', u'count': u'1'},
#    u'count': u'26',
#    u'dn': u'uid=adminbsc,ou=People,dc=uvm,dc=edu',
#    u'edupersonaffiliation': {u'0': u'Member', u'count': u'1'},
#    u'edupersonnickname': {u'0': u'ABSC', u'count': u'1'},
#    u'edupersonprimaryaffiliation': {u'0': u'Member', u'count': u'1'},
#    u'edupersonprincipalname': {u'0': u'adminbsc@uvm.edu', u'count': u'1'},
#    u'facsimiletelephonenumber': {u'0': u'(802) 656-2050', u'count': u'1'},
#    u'filter_field': u'cn',
#    u'from_filter': u'displayName',
#    u'gecos': {u'0': u'Administrative Business Service-Center', u'count': u'1'},
#    u'gidnumber': {u'0': u'100', u'count': u'1'},
#    u'homedirectory': {u'0': u'/users/a/d/adminbsc', u'count': u'1'},
#    u'loginshell': {u'0': u'/bin/bash', u'count': u'1'},
#    u'mail': {u'0': u'adminbsc@uvm.edu', u'count': u'1'},
#    u'mailroutingaddress': {u'0': u'adminbsc@msx-po.uvm.edu', u'count': u'1'},
#    u'sn': {u'0': u'Service-Center', u'count': u'1'},
#    u'uid': {u'0': u'adminbsc', u'count': u'1'},
#    u'uidnumber': {u'0': u'150604', u'count': u'1'},
#    u'uvmaltgid': {u'0': u'502', u'count': u'1'},
#    u'uvmalthomedir': {u'0': u'/Users/Customer', u'count': u'1'},
#    u'uvmaltuid': {u'0': u'502', u'count': u'1'},
#    u'uvmeduaffiliation': {u'0': u'Departmental Account', u'count': u'1'},
#    u'uvmedualias': {u'0': u'adminbsc', u'count': u'1'},
#    u'uvmedubroadcastflag': {u'0': u'a', u'count': u'1'},
#    u'uvmeduofficeaddress': {u'0': u'205 Waterman Building', u'count': u'1'},
#    u'uvmeduofficephone': {u'0': u'(802) 656-0100', u'count': u'1'},
#    u'uvmeduprimaryaffiliation': {u'0': u'Departmental Account',
#     u'count': u'1'},
#    u'uvmedusurname': {u'0': u'Service-Center', u'count': u'1'},
#    u'uvmeduuuid': {u'0': u'ca710bdc-8748-4864-be70-303778fe2b40',
#     u'count': u'1'}},
#   {u'0': u'uvmeduuuid',
#    u'1': u'uvmedualias',
#    u'10': u'uvmaltgid',
#    u'11': u'uvmalthomedir',
#    u'12': u'uidnumber',
#    u'13': u'gidnumber',
#    u'14': u'homedirectory',
#    u'15': u'loginshell',
#    u'16': u'edupersonprincipalname',
#    u'17': u'mailroutingaddress',
#    u'18': u'edupersonentitlement',
#    u'19': u'uvmeduaffiliation',
#    u'2': u'mail',
#    u'20': u'gecos',
#    u'21': u'edupersonprimaryaffiliation',
#    u'22': u'uvmeduprimaryaffiliation',
#    u'23': u'uvmedubroadcastflag',
#    u'24': u'displayname',
#    u'25': u'ou',
#    u'3': u'uid',
#    u'4': u'edupersonaffiliation',
#    u'5': u'cn',
#    u'6': u'givenname',
#    u'7': u'sn',
#    u'8': u'uvmedusurname',
#    u'9': u'uvmaltuid',
#    u'cn': {u'0': u'Abbie Claire McCabe', u'count': u'1'},
#    u'count': u'26',
#    u'displayname': {u'0': u'Abigail McCabe', u'count': u'1'},
#    u'dn': u'uid=acmccabe,ou=People,dc=uvm,dc=edu',
#    u'edupersonaffiliation': {u'0': u'Student',
#     u'1': u'Affiliate',
#     u'count': u'2'},
#    u'edupersonentitlement': {u'0': u'urn:mace:uvm.edu:ets:unix-login',
#     u'1': u'urn:mace:uvm.edu:ets:software-download',
#     u'2': u'urn:mace:uvm.edu:ets:unix-filespace',
#     u'3': u'urn:mace:uvm.edu:ets:email',
#     u'4': u'urn:mace:uvm.edu:ets:ad-login',
#     u'5': u'urn:mace:uvm.edu:ets:banner-access',
#     u'count': u'6'},
#    u'edupersonprimaryaffiliation': {u'0': u'Student', u'count': u'1'},
#    u'edupersonprincipalname': {u'0': u'acmccabe@uvm.edu', u'count': u'1'},
#    u'filter_field': u'cn',
#    u'from_filter': u'displayName',
#    u'gecos': {u'0': u'Abbie Claire McCabe', u'count': u'1'},
#    u'gidnumber': {u'0': u'100', u'count': u'1'},
#    u'givenname': {u'0': u'Abbie', u'count': u'1'},
#    u'homedirectory': {u'0': u'/users/a/c/acmccabe', u'count': u'1'},
#    u'loginshell': {u'0': u'/bin/bash', u'count': u'1'},
#    u'mail': {u'0': u'Abigail.C.McCabe@uvm.edu', u'count': u'1'},
#    u'mailroutingaddress': {u'0': u'acmccabe@msx-po.uvm.edu', u'count': u'1'},
#    u'ou': {u'0': u'Sophomore', u'count': u'1'},
#    u'sn': {u'0': u'McCabe', u'count': u'1'},
#    u'uid': {u'0': u'acmccabe', u'count': u'1'},
#    u'uidnumber': {u'0': u'291362', u'count': u'1'},
#    u'uvmaltgid': {u'0': u'502', u'count': u'1'},
#    u'uvmalthomedir': {u'0': u'/Users/Customer', u'count': u'1'},
#    u'uvmaltuid': {u'0': u'502', u'count': u'1'},
#    u'uvmeduaffiliation': {u'0': u'Current Degree Student',
#     u'1': u'Former Student',
#     u'count': u'2'},
#    u'uvmedualias': {u'0': u'Abigail.C.McCabe', u'count': u'1'},
#    u'uvmedubroadcastflag': {u'0': u'n', u'count': u'1'},
#    u'uvmeduprimaryaffiliation': {u'0': u'Current Degree Student',
#     u'count': u'1'},
#    u'uvmedusurname': {u'0': u'McCabe', u'count': u'1'},
#    u'uvmeduuuid': {u'0': u'0899c076-a6e3-11e6-9aac-8292cefaea91',
#     u'count': u'1'}}],
#  u'remote_user': u'',
#  u'request_num': u'1',
#  u'search': [u'ab', u'', u'', u''],
#  u'status': u'1'}

# %%
for i, person in enumerate(response_json["data"]):
    if i == 10: 
        break # Make sure we don't print too much
        
    print(person["edupersonprimaryaffiliation"]["0"], person["edupersonprincipalname"]["0"], person["cn"]["0"])
# Out:
# (u'Affiliate', u'asender@uvm.edu', u'Abraham Isaac Sender')
# (u'Faculty', u'acrocker@uvm.edu', u'Abigail Miles Crocker')
# (u'Faculty', u'aambaye@uvm.edu', u'Abiy B. Ambaye')
# (u'Staff', u'aldattil@uvm.edu', u'Abbey L. Peterson')
# (u'Faculty', u'avan@uvm.edu', u'Abby Katrien van den Berg')
# (u'Faculty', u'amcgowan@uvm.edu', u'Abigail S. McGowan')
# (u'Student', u'afsmith@uvm.edu', u'Abigayle Frances Smith')
# (u'Student', u'alangsne@uvm.edu', u'Abigail Elizabeth Langsner')
# (u'Faculty', u'atangada@uvm.edu', u'Abhilasha Tangada')
# (u'Faculty', u'awoodhea@uvm.edu', u'Abigail Rhodes Adler')

# %% [markdown]
# ### Explicit APIs
#
# Next, let's try a more typical example of an API. The perks of this approach: (a) send a request and get back JSON, (b) chances are that somebody else has created a Python wrapper for you, but keep in mind that (c) APIs have limits.
#
# Let's consider a common API example -- Twitter. To get started:
# - Get a key: https://apps.twitter.com/
# - Documentation: https://dev.twitter.com/rest/public
# - Find a library: https://dev.twitter.com/resources/twitter-libraries (We'll use https://github.com/tweepy/tweepy)
#
# Limitations: 100 messages / query, 180 messages every 15 min, & only the last seven days of data

# %%
# !pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /anaconda2/lib/python2.7/site-packages (3.6.0)
# Requirement already satisfied: requests>=2.11.1 in /anaconda2/lib/python2.7/site-packages (from tweepy) (2.18.4)
# Requirement already satisfied: PySocks>=1.5.7 in /anaconda2/lib/python2.7/site-packages (from tweepy) (1.6.7)
# Requirement already satisfied: six>=1.10.0 in /anaconda2/lib/python2.7/site-packages (from tweepy) (1.11.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /anaconda2/lib/python2.7/site-packages (from tweepy) (1.0.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda2/lib/python2.7/site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /anaconda2/lib/python2.7/site-packages (from requests>=2.11.1->tweepy) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /anaconda2/lib/python2.7/site-packages (from requests>=2.11.1->tweepy) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda2/lib/python2.7/site-packages (from requests>=2.11.1->tweepy) (2018.4.16)
# Requirement already satisfied: oauthlib>=0.6.2 in /anaconda2/lib/python2.7/site-packages (from requests-oauthlib>=0.7.0->tweepy) (2.1.0)

# %%
import tweepy
import time
import pickle

def twitter(d_keys,query):
    #Authtentify
    auth = tweepy.OAuthHandler(d_keys["CONSUMER_KEY"], d_keys["CONSUMER_SECRET"])
    auth.set_access_token(d_keys["ACCESS_KEY"], d_keys["ACCESS_SECRET"])
    api = tweepy.API(auth)

    # We want 1000 tweets
    num_results = 1000
    result_count = 0
    last_id = None
    
    # Max 180 tweets 15 min
    cumulative = 0

    #While we don't have them
    while (result_count <  num_results):
        previous_tweets = result_count
        # Ask for more tweets, starting in the 'last_id' (identifier of the tweet)
        results = api.search(q = query,
                              count = 90, max_id = last_id, result_type="recent")
                                # geocode = "{},{},{}km".format(latitude, longitude, max_range) #for geocode

        # For each tweet extract some info (JSON structure)
        for result in results:
            result_count += 1
            user = result.user.screen_name
            text = result.text
            followers_count = result.user.followers_count
            time_zone = result.user.time_zone
            print("_"*10)
            print(user,time_zone,followers_count)
            print(text)

        # Keep the last_id to know where to continue
        last_id = int(result.id)-1
        new_tweets = result_count - previous_tweets

        print ("Number of results: {} ({} new)".format(result_count,new_tweets))

        # If we don't get new tweets exit
        if new_tweets == 0: 
            break
        
        time.sleep(1)
        
        if ((result_count + 90) // 150) > cumulative:
            cumulative += 1
            time.sleep(15*60)


d_keys = pickle.load(open(".key","rb")) # Don't share your keys ;)
twitter(d_keys,"from:sfiscience")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-59-b7b51e12a636> in <module>()
#      53
#      54
# ---> 55 d_keys = pickle.load(open(".key","rb")) # Don't share your keys ;)
#      56 twitter(d_keys,"from:sfiscience")
#
# IOError: [Errno 2] No such file or directory: '.key'
